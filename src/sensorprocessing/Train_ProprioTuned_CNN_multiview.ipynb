# %% [markdown]
# # # Train a proprioception-tuned Multi-View CNN
#
# We create a sensor processing model using CNN-based visual encoding with multiple views
# finetuned with proprioception.
#
# This script handles training with two camera views, fusing the information
# to create a more robust representation of the robot state. We support both VGG19 and ResNet50 as base models.

# %%
import sys
sys.path.append("..")
from settings import Config

import pathlib
import torch
import torch.nn as nn
from torchvision import models, transforms
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, Dataset
import numpy as np

from behavior_cloning.demo_to_trainingdata import BCDemonstration
from robot.al5d_position_controller import RobotPosition
# Import the model classes from the sensor processing module
from sensorprocessing.sp_propriotuned_cnn_multiview import MultiViewVGG19Model, MultiViewResNetModel
from sensorprocessing.sp_propriotuned_cnn_multiview import MultiViewVGG19SensorProcessing, MultiViewResNetSensorProcessing

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# The experiment/run we are going to run: the specified model will be created
experiment = "sensorprocessing_propriotuned_cnn_multiview"
# run = "vgg19_128_multiview"
# run = "resnet50_128_multiview"
run = "vgg19_256_multiview"
# run = "resnet50_256_multiview"


exp = Config().get_experiment(experiment, run)
# Out:
# Loading pointer config file: /home/ssheikholeslami/.config/BerryPicker/mainsettings.yaml
# Loading machine-specific config file: /home/ssheikholeslami/SaharaBerryPickerData/settings-sahara.yaml
# No system dependent experiment file
#  /home/ssheikholeslami/SaharaBerryPickerData/experiments-Config/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview_sysdep.yaml,
#  that is ok, proceeding.
# Configuration for experiment: sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview successfully loaded

# %% [markdown]
# ### Create regression training data (image to proprioception)
# The training data (X, Y) is all the pictures from a demonstration with the corresponding proprioception data.

# %%
# Create output directory if it doesn't exist
data_dir = pathlib.Path(exp["data_dir"])
data_dir.mkdir(parents=True, exist_ok=True)
print(f"Data directory: {data_dir}")
# Out:
# Data directory: /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview

# %%
# Define a custom dataset for multi-view images
class MultiViewDataset(Dataset):
    def __init__(self, view_inputs, targets):
        """
        Dataset for handling multiple camera views

        Args:
            view_inputs: List of tensors, one per view [view1, view2, ...]
                Each view tensor has shape [num_samples, C, H, W]
            targets: Tensor of target values [num_samples, output_dim]
        """
        self.view_inputs = view_inputs  # List of tensors, one per view
        self.targets = targets
        self.num_samples = len(targets)

        # Verify all views have the same number of samples
        for view in view_inputs:
            assert len(view) == self.num_samples, "All views must have the same number of samples"

    def __len__(self):
        return self.num_samples

    def __getitem__(self, idx):
        # Get corresponding sample from each view
        views = [view[idx] for view in self.view_inputs]
        target = self.targets[idx]
        return views, target

def load_multiview_demonstrations(task, proprioception_input_file, proprioception_target_file, num_views=2):
    """
    Loads all the images of a task from multiple camera views, and processes it as two tensors
    as input and target data for proprioception training.

    Args:
        task: Task name to load demonstrations from
        proprioception_input_file: Path to save/load processed inputs
        proprioception_target_file: Path to save/load processed targets
        num_views: Number of camera views to process

    Returns:
        Dictionary containing training and validation data splits
    """

    retval = {}
    if proprioception_input_file.exists():
        print(f"Loading cached data from {proprioception_input_file}")
        retval["view_inputs"] = torch.load(proprioception_input_file, weights_only=True)
        retval["targets"] = torch.load(proprioception_target_file, weights_only=True)
    else:
        demos_dir = pathlib.Path(Config()["demos"]["directory"])
        task_dir = pathlib.Path(demos_dir, "demos", task)

        # Lists to store multi-view images and targets
        view_lists = {}  # Dictionary to organize views by camera
        targetlist = []

        print(f"Loading demonstrations from {task_dir}")
        for demo_dir in task_dir.iterdir():
            if not demo_dir.is_dir():
                continue

            print(f"Processing demonstration: {demo_dir.name}")
            # Create BCDemonstration with multi-camera support
            bcd = BCDemonstration(
                demo_dir,
                sensorprocessor=None
            )

            # Initialize view lists if not already done
            if not view_lists:
                for camera in bcd.cameras:
                    view_lists[camera] = []

            # Process each timestep
            for i in range(bcd.trim_from, bcd.trim_to):
                # Get all images for this timestep
                all_images = bcd.get_all_images(i)

                # If we don't have all required views, skip this timestep
                if len(all_images) < num_views:
                    print(f"  Skipping timestep {i} - only {len(all_images)}/{num_views} views available")
                    continue

                # Collect images from each camera
                for camera, (sensor_readings, _) in all_images.items():
                    if camera in view_lists:
                        view_lists[camera].append(sensor_readings[0])

                # Get the robot action for this timestep
                a = bcd.get_a(i)
                rp = RobotPosition.from_vector(a)
                anorm = rp.to_normalized_vector()
                targetlist.append(torch.from_numpy(anorm))

        # Ensure we have the same number of frames for each view
        min_frames = min(len(view_list) for view_list in view_lists.values())
        if min_frames < len(targetlist):
            print(f"Truncating dataset to {min_frames} frames (from {len(targetlist)})")
            targetlist = targetlist[:min_frames]
            for camera in view_lists:
                view_lists[camera] = view_lists[camera][:min_frames]

        # Stack tensors for each view
        view_tensors = []
        for camera in sorted(view_lists.keys())[:num_views]:  # Take only the required number of views
            view_tensors.append(torch.stack(view_lists[camera]))

        # Create multi-view input tensor list [num_views, num_samples, C, H, W]
        retval["view_inputs"] = view_tensors
        retval["targets"] = torch.stack(targetlist)

        # Save processed data
        torch.save(retval["view_inputs"], proprioception_input_file)
        torch.save(retval["targets"], proprioception_target_file)
        print(f"Saved {len(targetlist)} training examples with {num_views} views each")

    # Separate the training and validation data
    length = len(retval["targets"])
    rows = torch.randperm(length)

    # Shuffle targets
    shuffled_targets = retval["targets"][rows]

    # Shuffle each view input using the same row indices
    shuffled_view_inputs = []
    for view_tensor in retval["view_inputs"]:
        shuffled_view_inputs.append(view_tensor[rows])

    # Split into training (67%) and validation (33%) sets
    training_size = int(length * 0.67)

    # Training data
    retval["view_inputs_training"] = [view[:training_size] for view in shuffled_view_inputs]
    retval["targets_training"] = shuffled_targets[:training_size]

    # Validation data
    retval["view_inputs_validation"] = [view[training_size:] for view in shuffled_view_inputs]
    retval["targets_validation"] = shuffled_targets[training_size:]

    print(f"Created {training_size} training examples and {length - training_size} validation examples")
    return retval

# %%
# Main execution

# Load the training data
task = exp["proprioception_training_task"]
proprioception_input_file = pathlib.Path(exp["data_dir"], exp["proprioception_input_file"])
proprioception_target_file = pathlib.Path(exp["data_dir"], exp["proprioception_target_file"])
num_views = exp.get("num_views", 2)

tr = load_multiview_demonstrations(task, proprioception_input_file, proprioception_target_file, num_views)
view_inputs_training = tr["view_inputs_training"]
targets_training = tr["targets_training"]
view_inputs_validation = tr["view_inputs_validation"]
targets_validation = tr["targets_validation"]
# Out:
# Loading cached data from /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/train_inputs.pt
# Created 1205 training examples and 594 validation examples

# %% [markdown]
# ### Create a model that performs proprioception regression

# %%
# Create the model based on configuration
if exp['model'] == 'VGG19ProprioTunedRegression_multiview':
    # Create the VGG19-based multi-view model by using the class from sp_propriotuned_cnn.py
    model = MultiViewVGG19Model(exp, device)
    # Alternatively, we could also use the sensor processing class directly
    # sp = MultiViewVGG19SensorProcessing(exp, device)
    # model = sp.enc
elif exp['model'] == 'ResNetProprioTunedRegression_multiview':
    # Create the ResNet-based multi-view model by using the class from sp_propriotuned_cnn.py
    model = MultiViewResNetModel(exp, device)
    # Alternatively, we could also use the sensor processing class directly
    # sp = MultiViewResNetSensorProcessing(exp, device)
    # model = sp.enc
else:
    raise Exception(f"Unknown model {exp['model']}")
# Out:
# /apps/anaconda/anaconda-2023.09/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /apps/anaconda/anaconda-2023.09/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Create DataLoaders for batching
batch_size = exp.get('batch_size', 32)
train_dataset = MultiViewDataset(view_inputs_training, targets_training)
test_dataset = MultiViewDataset(view_inputs_validation, targets_validation)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
def train_and_save_multiview_model(model, criterion, optimizer, modelfile, device="cpu", epochs=20, scheduler=None, log_interval=1):
    """
    Trains and saves the multi-view CNN proprioception model

    Args:
        model: Multi-view CNN model
        criterion: Loss function
        optimizer: Optimizer
        modelfile: Path to save the final model
        device: Training device (cpu/cuda)
        epochs: Number of training epochs
        scheduler: Optional learning rate scheduler
        log_interval: How often to print logs
    """
    # Create checkpoint directory
    checkpoint_dir = modelfile.parent / "checkpoints"
    checkpoint_dir.mkdir(exist_ok=True)

    # Maximum number of checkpoints to keep
    max_checkpoints = 2

    # Function to extract epoch number from checkpoint file
    def get_epoch_number(checkpoint_file):
        try:
            filename = checkpoint_file.stem
            parts = filename.split('_')
            if len(parts) >= 2:
                return int(parts[1])
            return 0
        except:
            return 0

    # Keep track of the best validation loss
    best_val_loss = float('inf')
    start_epoch = 0

    # Check for existing checkpoints to resume from
    checkpoint_files = list(checkpoint_dir.glob("epoch_*.pth"))
    if checkpoint_files:
        # Sort by epoch number
        checkpoint_files.sort(key=get_epoch_number)

        # Get the most recent checkpoint
        latest_checkpoint = checkpoint_files[-1]
        epoch_num = get_epoch_number(latest_checkpoint)

        print(f"Found checkpoint from epoch {epoch_num}. Resuming training...")

        # Load checkpoint
        checkpoint = torch.load(latest_checkpoint, map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        start_epoch = checkpoint['epoch'] + 1
        best_val_loss = checkpoint.get('best_val_loss', float('inf'))

        print(f"Resuming from epoch {start_epoch}/{epochs} with best validation loss: {best_val_loss:.4f}")

    # Function to clean up old checkpoints
    def cleanup_old_checkpoints():
        checkpoint_files = list(checkpoint_dir.glob("epoch_*.pth"))
        checkpoint_files.sort(key=get_epoch_number)

        if len(checkpoint_files) > max_checkpoints:
            files_to_delete = checkpoint_files[:-max_checkpoints]
            for file_path in files_to_delete:
                try:
                    file_path.unlink()
                    print(f"Deleted old checkpoint: {file_path.name}")
                except Exception as e:
                    print(f"Failed to delete {file_path.name}: {e}")

    # Ensure model is on the right device
    model = model.to(device)
    criterion = criterion.to(device)

    # Training loop
    for epoch in range(start_epoch, epochs):
        print(f"Starting epoch {epoch+1}/{epochs}")

        # Training phase
        model.train()
        total_loss = 0
        for batch_idx, (batch_views, batch_y) in enumerate(train_loader):
            # Move views and targets to device
            batch_views = [view.to(device) for view in batch_views]
            batch_y = batch_y.to(device)

            # Forward pass
            predictions = model(batch_views)
            loss = criterion(predictions, batch_y)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            # Print progress every few batches
            if (batch_idx + 1) % 10 == 0:
                print(f"  Batch {batch_idx+1}/{len(train_loader)}, Loss: {loss.item():.4f}")

        avg_train_loss = total_loss / len(train_loader)

        # Validation phase
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for batch_views, batch_y in test_loader:
                batch_views = [view.to(device) for view in batch_views]
                batch_y = batch_y.to(device)

                predictions = model(batch_views)
                loss = criterion(predictions, batch_y)
                val_loss += loss.item()

        avg_val_loss = val_loss / len(test_loader)

        # Update learning rate if scheduler is provided
        if scheduler is not None:
            scheduler.step(avg_val_loss)

        # Save checkpoint for this epoch
        checkpoint_path = checkpoint_dir / f"epoch_{epoch:06d}.pth"
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'train_loss': avg_train_loss,
            'val_loss': avg_val_loss,
            'best_val_loss': best_val_loss
        }, checkpoint_path)
        print(f"Checkpoint saved to {checkpoint_path}")

        # Clean up old checkpoints
        cleanup_old_checkpoints()

        # Save the best model separately
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_model_path = checkpoint_dir / "best_model.pth"
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'train_loss': avg_train_loss,
                'val_loss': avg_val_loss,
                'best_val_loss': best_val_loss
            }, best_model_path)
            print(f"  New best model saved with validation loss: {best_val_loss:.4f}")

        # Log progress
        if (epoch + 1) % log_interval == 0:
            print(f'Epoch [{epoch+1}/{epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}')

    # Training completed
    print(f"Training complete. Best validation loss: {best_val_loss:.4f}")

    # Load the best model for final save
    best_model_path = checkpoint_dir / "best_model.pth"
    if best_model_path.exists():
        best_checkpoint = torch.load(best_model_path, map_location=device)
        model.load_state_dict(best_checkpoint['model_state_dict'])
        print(f"Loaded best model from epoch {best_checkpoint['epoch']+1} with loss {best_checkpoint['val_loss']:.4f}")

    # Save final model
    torch.save(model.state_dict(), modelfile)
    print(f"Final model saved to {modelfile}")

    return model

# %%
# Test functions
def test_multiview_model(model, test_view_inputs, test_targets, device, n_samples=5):
    """Test the multi-view CNN model on random examples."""
    if n_samples > len(test_targets):
        n_samples = len(test_targets)

    # Get random indices
    indices = torch.randperm(len(test_targets))[:n_samples]

    print("\nTesting multi-view CNN model on random examples:")
    print("-" * 60)

    # Ensure model is in evaluation mode
    model.eval()

    with torch.no_grad():
        for i, idx in enumerate(indices):
            # Get views and target
            views = [view[idx].unsqueeze(0).to(device) for view in test_view_inputs]
            target = test_targets[idx].cpu().numpy()

            # Get latent representation
            latent = model.encode_views(views)

            # Get prediction
            prediction = model.proprioceptor(latent)
            prediction = prediction.cpu().numpy().flatten()

            # Print the results
            print(f"Example {i+1}:")
            for j, view in enumerate(views):
                print(f"  View {j+1} shape: {view.shape}")
            print(f"  Latent shape: {latent.shape}")
            print(f"  Target position: {target}")
            print(f"  Predicted position: {prediction}")
            print(f"  Mean squared error: {np.mean((prediction - target) ** 2):.6f}")
            print()

# %%
def test_model_encoding(model, view_inputs_validation, device, n_samples=3):
    """Test the encoding functionality of the multi-view CNN model."""
    if n_samples > len(view_inputs_validation[0]):
        n_samples = len(view_inputs_validation[0])

    # Get first few samples
    indices = range(n_samples)

    print("\nTesting model encoding functionality:")
    print("-" * 60)

    # Get expected dimensions from model configuration
    latent_size = model.latent_size
    output_size = model.output_size

    # Ensure model is in evaluation mode
    model.eval()

    with torch.no_grad():
        for i in indices:
            # Get views
            views = [view[i].unsqueeze(0).to(device) for view in view_inputs_validation]

            print(f"\nSample {i+1}:")

            # Test feature extraction
            features_list = []
            for j, view in enumerate(views):
                features = model.feature_extractors[j](view)
                flat_features = model.flatten(features)
                features_list.append(flat_features)
                print(f"  View {j+1} features shape: {flat_features.shape}")

            # Test concatenated features
            concat_features = torch.cat(features_list, dim=1)
            print(f"  Concatenated features shape: {concat_features.shape}")

            # Test latent encoding
            latent = model.encode_views(views)
            print(f"  Latent representation shape: {latent.shape}")
            # Assert latent has correct shape
            assert latent.shape[1] == latent_size, f"Expected latent size {latent_size}, got {latent.shape[1]}"

            # Test full forward pass
            output = model.forward(views)
            print(f"  Model output shape: {output.shape}")
            # Assert output has correct shape
            assert output.shape[1] == output_size, f"Expected output size {output_size}, got {output.shape[1]}"

            # Test that the proprioceptor gives the expected output when fed the latent
            proprio_output = model.proprioceptor(latent)
            print(f"  Proprioceptor output shape: {proprio_output.shape}")
            # Assert proprioceptor output has correct shape
            assert proprio_output.shape[1] == output_size, f"Expected proprioceptor output size {output_size}, got {proprio_output.shape[1]}"

            # Verify that direct proprioceptor output matches the forward pass
            is_close = torch.allclose(output, proprio_output, rtol=1e-5, atol=1e-5)
            print(f"  Forward pass matches proprioceptor: {is_close}")
            assert is_close, "Forward pass output does not match proprioceptor output"

            print("  All shape assertions passed!")

# %%
def test_process_file(model, view_inputs_validation, n_samples=3):
    """Test the process_file method which handles view caching."""
    # Create a temporary sensor processing wrapper
    class TempSP:
        def __init__(self, model):
            self.enc = model
            self._view_cache = {}
            self._timestep_cache = {}
            self._current_timestep = None

        def process(self, views_list):
            self.enc.eval()
            with torch.no_grad():
                z = self.enc.encode_views(views_list)
            z = torch.squeeze(z)
            return z.cpu().numpy()

        def process_file(self, file_path, camera_id=None):
            # Simulate loading an image
            # In a real implementation, this would load from file_path
            # For testing, we'll just sample from our validation set

            # Set a camera ID if none provided
            if camera_id is None:
                camera_id = f"camera_{np.random.randint(0, model.num_views)}"

            # Get timestep from filename if possible
            try:
                filename = pathlib.Path(file_path).stem
                timestep = int(filename.split('_')[0])
                self._current_timestep = timestep
            except:
                timestep = None

            # Get a validation image
            idx = np.random.randint(0, len(view_inputs_validation[0]))
            view_idx = int(camera_id.split('_')[-1]) if camera_id.startswith('camera_') else 0
            view_idx = min(view_idx, len(view_inputs_validation)-1)
            sensor_readings = view_inputs_validation[view_idx][idx].unsqueeze(0)

            # Update cache
            if timestep is not None:
                if timestep not in self._timestep_cache:
                    self._timestep_cache[timestep] = {}
                self._timestep_cache[timestep][camera_id] = sensor_readings

            self._view_cache[camera_id] = sensor_readings

            # Prepare views for processing
            views_list = []
            required_cameras = model.num_views

            # Try timestep cache first
            if timestep is not None and timestep in self._timestep_cache:
                timestep_views = self._timestep_cache[timestep]
                if len(timestep_views) == required_cameras:
                    for cam in sorted(timestep_views.keys())[:required_cameras]:
                        views_list.append(timestep_views[cam])
                    return self.process(views_list)

            # Use global cache
            views_list = [sensor_readings]
            other_cameras = [cam for cam in sorted(self._view_cache.keys()) if cam != camera_id]

            while len(views_list) < required_cameras and other_cameras:
                camera = other_cameras.pop(0)
                views_list.append(self._view_cache[camera])

            # Fill with duplicates if needed
            while len(views_list) < required_cameras:
                views_list.append(sensor_readings)

            return self.process(views_list)

    if n_samples > len(view_inputs_validation[0]):
        n_samples = len(view_inputs_validation[0])

    print("\nTesting process_file method with view caching:")
    print("-" * 60)

    # Create temporary sensor processor
    sp = TempSP(model)

    # Create mock file paths
    for i in range(n_samples):
        print(f"\nTest {i+1}:")

        # Test with one camera first
        first_camera = "camera_0"
        file_path_1 = f"{i+1:05d}_{first_camera}.jpg"
        latent_1 = sp.process_file(file_path_1, camera_id=first_camera)
        print(f"  Processed with camera 0, latent shape: {latent_1.shape}")

        # Now test with second camera, should use first camera from cache
        second_camera = "camera_1"
        file_path_2 = f"{i+1:05d}_{second_camera}.jpg"
        latent_2 = sp.process_file(file_path_2, camera_id=second_camera)
        print(f"  Processed with camera 1, latent shape: {latent_2.shape}")

        # Test cache recovery - use a different timestep
        file_path_3 = f"{i+2:05d}_{first_camera}.jpg"
        latent_3 = sp.process_file(file_path_3, camera_id=first_camera)
        print(f"  Processed with camera 0 (new timestep), latent shape: {latent_3.shape}")

        # Test cross-timestep behavior
        file_path_4 = f"{i+2:05d}_{second_camera}.jpg"
        latent_4 = sp.process_file(file_path_4, camera_id=second_camera)
        print(f"  Processed with camera 1 (new timestep), latent shape: {latent_4.shape}")

        # Verify that latent representations have correct dimensions
        assert latent_1.shape[0] == model.latent_size, f"Expected latent size {model.latent_size}, got {latent_1.shape[0]}"
        assert latent_2.shape[0] == model.latent_size, f"Expected latent size {model.latent_size}, got {latent_2.shape[0]}"

        print("  All shape assertions passed!")

# %%
# Test data visualization - show some predictions vs targets
def visualize_model_predictions(model, view_inputs_validation, targets_validation, device, n_samples=5):
    """Visualize model predictions compared to ground truth targets"""
    if n_samples > len(targets_validation):
        n_samples = len(targets_validation)

    # Get random indices
    indices = torch.randperm(len(targets_validation))[:n_samples]

    print("\nComparing model predictions with ground truth:")
    print("-" * 60)

    # Field names for robot position
    field_names = ["height", "distance", "heading", "wrist_angle", "wrist_rotation", "gripper"]

    # Error metrics
    total_mse = 0
    total_mae = 0

    # Ensure model is in evaluation mode
    model.eval()

    with torch.no_grad():
        for i, idx in enumerate(indices):
            # Get views and ground truth
            views = [view[idx].unsqueeze(0).to(device) for view in view_inputs_validation]
            ground_truth = targets_validation[idx].cpu().numpy()

            # Get model prediction
            prediction = model(views).cpu().numpy().flatten()

            # Calculate errors
            mse = np.mean((prediction - ground_truth) ** 2)
            mae = np.mean(np.abs(prediction - ground_truth))
            total_mse += mse
            total_mae += mae

            # Print comparison
            print(f"\nSample {i+1}:")
            print("  Field                 | Ground Truth | Prediction  | Difference")
            print("  ---------------------|--------------|-------------|------------")

            for j, field in enumerate(field_names):
                diff = prediction[j] - ground_truth[j]
                print(f"  {field.ljust(20)} | {ground_truth[j]:12.4f} | {prediction[j]:11.4f} | {diff:10.4f}")

            print(f"  MSE: {mse:.6f}, MAE: {mae:.6f}")

    # Print average errors
    avg_mse = total_mse / n_samples
    avg_mae = total_mae / n_samples
    print("\nAverage errors across samples:")
    print(f"  Mean Squared Error: {avg_mse:.6f}")
    print(f"  Mean Absolute Error: {avg_mae:.6f}")

# %%
# Test for the model's ability to handle noisy or missing views
def test_model_robustness(model, view_inputs_validation, targets_validation, device, n_samples=3):
    """Test the model's robustness to imperfect view data"""
    if n_samples > len(targets_validation):
        n_samples = len(targets_validation)

    # Get random indices
    indices = torch.randperm(len(targets_validation))[:n_samples]

    print("\nTesting model robustness to imperfect views:")
    print("-" * 60)

    # Ensure model is in evaluation mode
    model.eval()

    with torch.no_grad():
        for i, idx in enumerate(indices):
            # Get views and ground truth
            views_original = [view[idx].unsqueeze(0).to(device) for view in view_inputs_validation]
            ground_truth = targets_validation[idx].cpu().numpy()

            # Case 1: Normal prediction with clean views
            prediction_clean = model(views_original).cpu().numpy().flatten()

            # Case 2: Add Gaussian noise to one view
            views_noisy = views_original.copy()
            noise = torch.randn_like(views_noisy[0]) * 0.1
            views_noisy[0] = views_noisy[0] + noise
            prediction_noisy = model(views_noisy).cpu().numpy().flatten()

            # Case 3: Duplicate one view (simulating missing view)
            views_duplicate = [views_original[0], views_original[0]]  # Use first view twice
            prediction_duplicate = model(views_duplicate).cpu().numpy().flatten()

            # Calculate errors
            mse_clean = np.mean((prediction_clean - ground_truth) ** 2)
            mse_noisy = np.mean((prediction_noisy - ground_truth) ** 2)
            mse_duplicate = np.mean((prediction_duplicate - ground_truth) ** 2)

            # Print results
            print(f"\nSample {i+1}:")
            print(f"  Clean views MSE: {mse_clean:.6f}")
            print(f"  Noisy view MSE: {mse_noisy:.6f}")
            print(f"  Duplicate view MSE: {mse_duplicate:.6f}")
            print(f"  Noise impact: {((mse_noisy - mse_clean) / mse_clean) * 100:.2f}% increase in error")
            print(f"  Missing view impact: {((mse_duplicate - mse_clean) / mse_clean) * 100:.2f}% increase in error")

# %%
# Print model architecture summary
print(f"Created {exp['model']} with {sum(p.numel() for p in model.parameters())} parameters")
print(f"Number of views: {num_views}")
print(f"Latent dimension: {exp['latent_size']}")
print(f"Output dimension: {exp['output_size']}")
# Out:
# Created VGG19ProprioTunedRegression_multiview with 73776582 parameters
# Number of views: 2
# Latent dimension: 256
# Output dimension: 6

# %%
expected_views = exp.get("num_views", 2)  # Default to 2 if not specified

# Check if model matches the configured number of views
if hasattr(model, 'feature_extractors') and isinstance(model.feature_extractors, nn.ModuleList):
    actual_views = len(model.feature_extractors)
    if actual_views == expected_views:
        print(f"Model confirmed as {expected_views}-view configuration")
    else:
        print(f"WARNING: Model supports {actual_views} views, but configuration specifies {expected_views} views")
else:
    print(f"WARNING: This appears to be a single-view model, not a {expected_views}-view model")
# Out:
# Model confirmed as 2-view configuration

# %%
# Select loss function
loss_type = exp.get('loss', 'MSELoss')
if loss_type == 'MSELoss':
    criterion = nn.MSELoss()
elif loss_type == 'L1Loss':
    criterion = nn.L1Loss()
else:
    criterion = nn.MSELoss()  # Default to MSE

# Set up optimizer with appropriate learning rate and weight decay
optimizer = optim.Adam(
    model.parameters(),
    lr=exp.get('learning_rate', 0.001),
    weight_decay=exp.get('weight_decay', 0.01)
)

# Optional learning rate scheduler
lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=3, verbose=True
)
# Out:
# /apps/anaconda/anaconda-2023.09/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
# Train the model
modelfile = pathlib.Path(exp["data_dir"], exp["proprioception_mlp_model_file"])
epochs = exp.get("epochs", 20)

# Check if model exists already
if modelfile.exists() and exp.get("reload_existing_model", True):
    print(f"Loading existing final model from {modelfile}")
    model.load_state_dict(torch.load(modelfile, map_location=device))

    # Evaluate the loaded model
    model.eval()
    with torch.no_grad():
        val_loss = 0
        for batch_views, batch_y in test_loader:
            # Move views and targets to device
            batch_views = [view.to(device) for view in batch_views]
            batch_y = batch_y.to(device)

            predictions = model(batch_views)
            loss = criterion(predictions, batch_y)
            val_loss += loss.item()

        avg_val_loss = val_loss / len(test_loader)
        print(f"Loaded model validation loss: {avg_val_loss:.4f}")

    # Test the loaded model
    test_multiview_model(model, view_inputs_validation, targets_validation, device)
else:
    # Check for checkpoints to resume from, otherwise start fresh training
    checkpoint_dir = modelfile.parent / "checkpoints"
    checkpoint_dir.mkdir(exist_ok=True)

    # Use the get_epoch_number function for reliable sorting
    def get_epoch_number(checkpoint_file):
        try:
            filename = checkpoint_file.stem
            parts = filename.split('_')
            if len(parts) >= 2:
                return int(parts[1])
            return 0
        except:
            return 0

    checkpoint_files = list(checkpoint_dir.glob("epoch_*.pth"))
    if checkpoint_files:
        # Sort by epoch number
        checkpoint_files.sort(key=get_epoch_number)
        latest_epoch = get_epoch_number(checkpoint_files[-1])
        print(f"Found checkpoints up to epoch {latest_epoch}. Will resume training from last checkpoint.")
    else:
        print(f"Starting new training for {epochs} epochs")

    # Train the model
    model = train_and_save_multiview_model(
        model, criterion, optimizer, modelfile,
        device=device, epochs=epochs, scheduler=lr_scheduler
    )

    # Test the trained model
    test_multiview_model(model, view_inputs_validation, targets_validation, device)
# Out:
# Found checkpoints up to epoch 79. Will resume training from last checkpoint.
# Found checkpoint from epoch 79. Resuming training...
# /tmp/ipykernel_677713/2315922466.py:50: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(latest_checkpoint, map_location=device)
# Resuming from epoch 80/300 with best validation loss: 0.0154
# Starting epoch 81/300
#   Batch 10/38, Loss: 0.0170
#   Batch 20/38, Loss: 0.0159
#   Batch 30/38, Loss: 0.0136
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000080.pth
# Deleted old checkpoint: epoch_000078.pth
#   New best model saved with validation loss: 0.0145
# Epoch [81/300], Train Loss: 0.0163, Val Loss: 0.0145
# Starting epoch 82/300
#   Batch 10/38, Loss: 0.0163
#   Batch 20/38, Loss: 0.0135
#   Batch 30/38, Loss: 0.0168
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000081.pth
# Deleted old checkpoint: epoch_000079.pth
# Epoch [82/300], Train Loss: 0.0163, Val Loss: 0.0146
# Starting epoch 83/300
#   Batch 10/38, Loss: 0.0147
#   Batch 20/38, Loss: 0.0162
#   Batch 30/38, Loss: 0.0145
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000082.pth
# Deleted old checkpoint: epoch_000080.pth
# Epoch [83/300], Train Loss: 0.0161, Val Loss: 0.0147
# Starting epoch 84/300
#   Batch 10/38, Loss: 0.0161
#   Batch 20/38, Loss: 0.0192
#   Batch 30/38, Loss: 0.0169
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000083.pth
# Deleted old checkpoint: epoch_000081.pth
# Epoch [84/300], Train Loss: 0.0161, Val Loss: 0.0147
# Starting epoch 85/300
#   Batch 10/38, Loss: 0.0162
#   Batch 20/38, Loss: 0.0170
#   Batch 30/38, Loss: 0.0172
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000084.pth
# Deleted old checkpoint: epoch_000082.pth
# Epoch [85/300], Train Loss: 0.0159, Val Loss: 0.0147
# Starting epoch 86/300
#   Batch 10/38, Loss: 0.0172
#   Batch 20/38, Loss: 0.0191
#   Batch 30/38, Loss: 0.0125
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000085.pth
# Deleted old checkpoint: epoch_000083.pth
# Epoch [86/300], Train Loss: 0.0157, Val Loss: 0.0148
# Starting epoch 87/300
#   Batch 10/38, Loss: 0.0175
#   Batch 20/38, Loss: 0.0168
#   Batch 30/38, Loss: 0.0185
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000086.pth
# Deleted old checkpoint: epoch_000084.pth
# Epoch [87/300], Train Loss: 0.0158, Val Loss: 0.0148
# Starting epoch 88/300
#   Batch 10/38, Loss: 0.0130
#   Batch 20/38, Loss: 0.0173
#   Batch 30/38, Loss: 0.0144
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000087.pth
# Deleted old checkpoint: epoch_000085.pth
# Epoch [88/300], Train Loss: 0.0159, Val Loss: 0.0148
# Starting epoch 89/300
#   Batch 10/38, Loss: 0.0160
#   Batch 20/38, Loss: 0.0205
#   Batch 30/38, Loss: 0.0191
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000088.pth
# Deleted old checkpoint: epoch_000086.pth
# Epoch [89/300], Train Loss: 0.0158, Val Loss: 0.0148
# Starting epoch 90/300
#   Batch 10/38, Loss: 0.0111
#   Batch 20/38, Loss: 0.0150
#   Batch 30/38, Loss: 0.0154
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000089.pth
# Deleted old checkpoint: epoch_000087.pth
# Epoch [90/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 91/300
#   Batch 10/38, Loss: 0.0136
#   Batch 20/38, Loss: 0.0153
#   Batch 30/38, Loss: 0.0141
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000090.pth
# Deleted old checkpoint: epoch_000088.pth
# Epoch [91/300], Train Loss: 0.0159, Val Loss: 0.0148
# Starting epoch 92/300
#   Batch 10/38, Loss: 0.0134
#   Batch 20/38, Loss: 0.0141
#   Batch 30/38, Loss: 0.0123
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000091.pth
# Deleted old checkpoint: epoch_000089.pth
# Epoch [92/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 93/300
#   Batch 10/38, Loss: 0.0185
#   Batch 20/38, Loss: 0.0183
#   Batch 30/38, Loss: 0.0191
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000092.pth
# Deleted old checkpoint: epoch_000090.pth
# Epoch [93/300], Train Loss: 0.0158, Val Loss: 0.0148
# Starting epoch 94/300
#   Batch 10/38, Loss: 0.0169
#   Batch 20/38, Loss: 0.0158
#   Batch 30/38, Loss: 0.0181
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000093.pth
# Deleted old checkpoint: epoch_000091.pth
# Epoch [94/300], Train Loss: 0.0158, Val Loss: 0.0148
# Starting epoch 95/300
#   Batch 10/38, Loss: 0.0194
#   Batch 20/38, Loss: 0.0175
#   Batch 30/38, Loss: 0.0205
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000094.pth
# Deleted old checkpoint: epoch_000092.pth
# Epoch [95/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 96/300
#   Batch 10/38, Loss: 0.0106
#   Batch 20/38, Loss: 0.0187
#   Batch 30/38, Loss: 0.0146
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000095.pth
# Deleted old checkpoint: epoch_000093.pth
# Epoch [96/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 97/300
#   Batch 10/38, Loss: 0.0132
#   Batch 20/38, Loss: 0.0152
#   Batch 30/38, Loss: 0.0191
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000096.pth
# Deleted old checkpoint: epoch_000094.pth
# Epoch [97/300], Train Loss: 0.0157, Val Loss: 0.0148
# Starting epoch 98/300
#   Batch 10/38, Loss: 0.0148
#   Batch 20/38, Loss: 0.0217
#   Batch 30/38, Loss: 0.0142
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000097.pth
# Deleted old checkpoint: epoch_000095.pth
# Epoch [98/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 99/300
#   Batch 10/38, Loss: 0.0150
#   Batch 20/38, Loss: 0.0200
#   Batch 30/38, Loss: 0.0153
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000098.pth
# Deleted old checkpoint: epoch_000096.pth
# Epoch [99/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 100/300
#   Batch 10/38, Loss: 0.0142
#   Batch 20/38, Loss: 0.0151
#   Batch 30/38, Loss: 0.0183
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000099.pth
# Deleted old checkpoint: epoch_000097.pth
# Epoch [100/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 101/300
#   Batch 10/38, Loss: 0.0187
#   Batch 20/38, Loss: 0.0158
#   Batch 30/38, Loss: 0.0125
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000100.pth
# Deleted old checkpoint: epoch_000098.pth
# Epoch [101/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 102/300
#   Batch 10/38, Loss: 0.0139
#   Batch 20/38, Loss: 0.0161
#   Batch 30/38, Loss: 0.0133
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000101.pth
# Deleted old checkpoint: epoch_000099.pth
# Epoch [102/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 103/300
#   Batch 10/38, Loss: 0.0134
#   Batch 20/38, Loss: 0.0156
#   Batch 30/38, Loss: 0.0155
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000102.pth
# Deleted old checkpoint: epoch_000100.pth
# Epoch [103/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 104/300
#   Batch 10/38, Loss: 0.0166
#   Batch 20/38, Loss: 0.0146
#   Batch 30/38, Loss: 0.0143
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000103.pth
# Deleted old checkpoint: epoch_000101.pth
# Epoch [104/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 105/300
#   Batch 10/38, Loss: 0.0192
#   Batch 20/38, Loss: 0.0129
#   Batch 30/38, Loss: 0.0149
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000104.pth
# Deleted old checkpoint: epoch_000102.pth
# Epoch [105/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 106/300
#   Batch 10/38, Loss: 0.0147
#   Batch 20/38, Loss: 0.0177
#   Batch 30/38, Loss: 0.0131
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000105.pth
# Deleted old checkpoint: epoch_000103.pth
# Epoch [106/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 107/300
#   Batch 10/38, Loss: 0.0153
#   Batch 20/38, Loss: 0.0184
#   Batch 30/38, Loss: 0.0167
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000106.pth
# Deleted old checkpoint: epoch_000104.pth
# Epoch [107/300], Train Loss: 0.0155, Val Loss: 0.0149
# Starting epoch 108/300
#   Batch 10/38, Loss: 0.0157
#   Batch 20/38, Loss: 0.0161
#   Batch 30/38, Loss: 0.0173
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000107.pth
# Deleted old checkpoint: epoch_000105.pth
# Epoch [108/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 109/300
#   Batch 10/38, Loss: 0.0147
#   Batch 20/38, Loss: 0.0158
#   Batch 30/38, Loss: 0.0169
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000108.pth
# Deleted old checkpoint: epoch_000106.pth
# Epoch [109/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 110/300
#   Batch 10/38, Loss: 0.0128
#   Batch 20/38, Loss: 0.0158
#   Batch 30/38, Loss: 0.0167
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000109.pth
# Deleted old checkpoint: epoch_000107.pth
# Epoch [110/300], Train Loss: 0.0155, Val Loss: 0.0149
# Starting epoch 111/300
#   Batch 10/38, Loss: 0.0179
#   Batch 20/38, Loss: 0.0194
#   Batch 30/38, Loss: 0.0157
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000110.pth
# Deleted old checkpoint: epoch_000108.pth
# Epoch [111/300], Train Loss: 0.0155, Val Loss: 0.0149
# Starting epoch 112/300
#   Batch 10/38, Loss: 0.0133
#   Batch 20/38, Loss: 0.0110
#   Batch 30/38, Loss: 0.0140
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000111.pth
# Deleted old checkpoint: epoch_000109.pth
# Epoch [112/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 113/300
#   Batch 10/38, Loss: 0.0166
#   Batch 20/38, Loss: 0.0145
#   Batch 30/38, Loss: 0.0156
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000112.pth
# Deleted old checkpoint: epoch_000110.pth
# Epoch [113/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 114/300
#   Batch 10/38, Loss: 0.0124
#   Batch 20/38, Loss: 0.0168
#   Batch 30/38, Loss: 0.0184
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000113.pth
# Deleted old checkpoint: epoch_000111.pth
# Epoch [114/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 115/300
#   Batch 10/38, Loss: 0.0145
#   Batch 20/38, Loss: 0.0162
#   Batch 30/38, Loss: 0.0207
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000114.pth
# Deleted old checkpoint: epoch_000112.pth
# Epoch [115/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 116/300
#   Batch 10/38, Loss: 0.0168
#   Batch 20/38, Loss: 0.0161
#   Batch 30/38, Loss: 0.0150
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000115.pth
# Deleted old checkpoint: epoch_000113.pth
# Epoch [116/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 117/300
#   Batch 10/38, Loss: 0.0168
#   Batch 20/38, Loss: 0.0168
#   Batch 30/38, Loss: 0.0168
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000116.pth
# Deleted old checkpoint: epoch_000114.pth
# Epoch [117/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 118/300
#   Batch 10/38, Loss: 0.0148
#   Batch 20/38, Loss: 0.0175
#   Batch 30/38, Loss: 0.0162
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000117.pth
# Deleted old checkpoint: epoch_000115.pth
# Epoch [118/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 119/300
#   Batch 10/38, Loss: 0.0185
#   Batch 20/38, Loss: 0.0131
#   Batch 30/38, Loss: 0.0164
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000118.pth
# Deleted old checkpoint: epoch_000116.pth
# Epoch [119/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 120/300
#   Batch 10/38, Loss: 0.0164
#   Batch 20/38, Loss: 0.0155
#   Batch 30/38, Loss: 0.0172
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000119.pth
# Deleted old checkpoint: epoch_000117.pth
# Epoch [120/300], Train Loss: 0.0155, Val Loss: 0.0149
# Starting epoch 121/300
#   Batch 10/38, Loss: 0.0112
#   Batch 20/38, Loss: 0.0141
#   Batch 30/38, Loss: 0.0174
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000120.pth
# Deleted old checkpoint: epoch_000118.pth
# Epoch [121/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 122/300
#   Batch 10/38, Loss: 0.0155
#   Batch 20/38, Loss: 0.0167
#   Batch 30/38, Loss: 0.0162
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000121.pth
# Deleted old checkpoint: epoch_000119.pth
# Epoch [122/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 123/300
#   Batch 10/38, Loss: 0.0154
#   Batch 20/38, Loss: 0.0144
#   Batch 30/38, Loss: 0.0148
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000122.pth
# Deleted old checkpoint: epoch_000120.pth
# Epoch [123/300], Train Loss: 0.0159, Val Loss: 0.0149
# Starting epoch 124/300
#   Batch 10/38, Loss: 0.0147
#   Batch 20/38, Loss: 0.0188
#   Batch 30/38, Loss: 0.0145
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000123.pth
# Deleted old checkpoint: epoch_000121.pth
# Epoch [124/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 125/300
#   Batch 10/38, Loss: 0.0172
#   Batch 20/38, Loss: 0.0134
#   Batch 30/38, Loss: 0.0152
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000124.pth
# Deleted old checkpoint: epoch_000122.pth
# Epoch [125/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 126/300
#   Batch 10/38, Loss: 0.0117
#   Batch 20/38, Loss: 0.0157
#   Batch 30/38, Loss: 0.0152
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000125.pth
# Deleted old checkpoint: epoch_000123.pth
# Epoch [126/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 127/300
#   Batch 10/38, Loss: 0.0128
#   Batch 20/38, Loss: 0.0172
#   Batch 30/38, Loss: 0.0170
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000126.pth
# Deleted old checkpoint: epoch_000124.pth
# Epoch [127/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 128/300
#   Batch 10/38, Loss: 0.0163
#   Batch 20/38, Loss: 0.0196
#   Batch 30/38, Loss: 0.0150
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000127.pth
# Deleted old checkpoint: epoch_000125.pth
# Epoch [128/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 129/300
#   Batch 10/38, Loss: 0.0194
#   Batch 20/38, Loss: 0.0174
#   Batch 30/38, Loss: 0.0157
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000128.pth
# Deleted old checkpoint: epoch_000126.pth
# Epoch [129/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 130/300
#   Batch 10/38, Loss: 0.0143
#   Batch 20/38, Loss: 0.0187
#   Batch 30/38, Loss: 0.0120
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000129.pth
# Deleted old checkpoint: epoch_000127.pth
# Epoch [130/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 131/300
#   Batch 10/38, Loss: 0.0188
#   Batch 20/38, Loss: 0.0115
#   Batch 30/38, Loss: 0.0200
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000130.pth
# Deleted old checkpoint: epoch_000128.pth
# Epoch [131/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 132/300
#   Batch 10/38, Loss: 0.0143
#   Batch 20/38, Loss: 0.0180
#   Batch 30/38, Loss: 0.0172
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000131.pth
# Deleted old checkpoint: epoch_000129.pth
# Epoch [132/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 133/300
#   Batch 10/38, Loss: 0.0179
#   Batch 20/38, Loss: 0.0165
#   Batch 30/38, Loss: 0.0142
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000132.pth
# Deleted old checkpoint: epoch_000130.pth
# Epoch [133/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 134/300
#   Batch 10/38, Loss: 0.0147
#   Batch 20/38, Loss: 0.0142
#   Batch 30/38, Loss: 0.0143
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000133.pth
# Deleted old checkpoint: epoch_000131.pth
# Epoch [134/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 135/300
#   Batch 10/38, Loss: 0.0134
#   Batch 20/38, Loss: 0.0135
#   Batch 30/38, Loss: 0.0192
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000134.pth
# Deleted old checkpoint: epoch_000132.pth
# Epoch [135/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 136/300
#   Batch 10/38, Loss: 0.0155
#   Batch 20/38, Loss: 0.0188
#   Batch 30/38, Loss: 0.0140
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000135.pth
# Deleted old checkpoint: epoch_000133.pth
# Epoch [136/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 137/300
#   Batch 10/38, Loss: 0.0136
#   Batch 20/38, Loss: 0.0145
#   Batch 30/38, Loss: 0.0154
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000136.pth
# Deleted old checkpoint: epoch_000134.pth
# Epoch [137/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 138/300
#   Batch 10/38, Loss: 0.0170
#   Batch 20/38, Loss: 0.0151
#   Batch 30/38, Loss: 0.0175
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000137.pth
# Deleted old checkpoint: epoch_000135.pth
# Epoch [138/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 139/300
#   Batch 10/38, Loss: 0.0166
#   Batch 20/38, Loss: 0.0168
#   Batch 30/38, Loss: 0.0137
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000138.pth
# Deleted old checkpoint: epoch_000136.pth
# Epoch [139/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 140/300
#   Batch 10/38, Loss: 0.0124
#   Batch 20/38, Loss: 0.0200
#   Batch 30/38, Loss: 0.0176
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000139.pth
# Deleted old checkpoint: epoch_000137.pth
# Epoch [140/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 141/300
#   Batch 10/38, Loss: 0.0179
#   Batch 20/38, Loss: 0.0164
#   Batch 30/38, Loss: 0.0186
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000140.pth
# Deleted old checkpoint: epoch_000138.pth
# Epoch [141/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 142/300
#   Batch 10/38, Loss: 0.0169
#   Batch 20/38, Loss: 0.0157
#   Batch 30/38, Loss: 0.0152
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000141.pth
# Deleted old checkpoint: epoch_000139.pth
# Epoch [142/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 143/300
#   Batch 10/38, Loss: 0.0102
#   Batch 20/38, Loss: 0.0161
#   Batch 30/38, Loss: 0.0132
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000142.pth
# Deleted old checkpoint: epoch_000140.pth
# Epoch [143/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 144/300
#   Batch 10/38, Loss: 0.0154
#   Batch 20/38, Loss: 0.0141
#   Batch 30/38, Loss: 0.0138
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000143.pth
# Deleted old checkpoint: epoch_000141.pth
# Epoch [144/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 145/300
#   Batch 10/38, Loss: 0.0145
#   Batch 20/38, Loss: 0.0137
#   Batch 30/38, Loss: 0.0152
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000144.pth
# Deleted old checkpoint: epoch_000142.pth
# Epoch [145/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 146/300
#   Batch 10/38, Loss: 0.0121
#   Batch 20/38, Loss: 0.0214
#   Batch 30/38, Loss: 0.0171
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000145.pth
# Deleted old checkpoint: epoch_000143.pth
# Epoch [146/300], Train Loss: 0.0154, Val Loss: 0.0149
# Starting epoch 147/300
#   Batch 10/38, Loss: 0.0174
#   Batch 20/38, Loss: 0.0120
#   Batch 30/38, Loss: 0.0163
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000146.pth
# Deleted old checkpoint: epoch_000144.pth
# Epoch [147/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 148/300
#   Batch 10/38, Loss: 0.0166
#   Batch 20/38, Loss: 0.0148
#   Batch 30/38, Loss: 0.0139
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000147.pth
# Deleted old checkpoint: epoch_000145.pth
# Epoch [148/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 149/300
#   Batch 10/38, Loss: 0.0166
#   Batch 20/38, Loss: 0.0113
#   Batch 30/38, Loss: 0.0118
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000148.pth
# Deleted old checkpoint: epoch_000146.pth
# Epoch [149/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 150/300
#   Batch 10/38, Loss: 0.0183
#   Batch 20/38, Loss: 0.0160
#   Batch 30/38, Loss: 0.0155
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000149.pth
# Deleted old checkpoint: epoch_000147.pth
# Epoch [150/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 151/300
#   Batch 10/38, Loss: 0.0166
#   Batch 20/38, Loss: 0.0178
#   Batch 30/38, Loss: 0.0186
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000150.pth
# Deleted old checkpoint: epoch_000148.pth
# Epoch [151/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 152/300
#   Batch 10/38, Loss: 0.0144
#   Batch 20/38, Loss: 0.0196
#   Batch 30/38, Loss: 0.0147
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000151.pth
# Deleted old checkpoint: epoch_000149.pth
# Epoch [152/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 153/300
#   Batch 10/38, Loss: 0.0137
#   Batch 20/38, Loss: 0.0140
#   Batch 30/38, Loss: 0.0148
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000152.pth
# Deleted old checkpoint: epoch_000150.pth
# Epoch [153/300], Train Loss: 0.0155, Val Loss: 0.0149
# Starting epoch 154/300
#   Batch 10/38, Loss: 0.0135
#   Batch 20/38, Loss: 0.0160
#   Batch 30/38, Loss: 0.0142
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000153.pth
# Deleted old checkpoint: epoch_000151.pth
# Epoch [154/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 155/300
#   Batch 10/38, Loss: 0.0139
#   Batch 20/38, Loss: 0.0147
#   Batch 30/38, Loss: 0.0132
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000154.pth
# Deleted old checkpoint: epoch_000152.pth
# Epoch [155/300], Train Loss: 0.0155, Val Loss: 0.0149
# Starting epoch 156/300
#   Batch 10/38, Loss: 0.0196
#   Batch 20/38, Loss: 0.0156
#   Batch 30/38, Loss: 0.0146
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000155.pth
# Deleted old checkpoint: epoch_000153.pth
# Epoch [156/300], Train Loss: 0.0159, Val Loss: 0.0149
# Starting epoch 157/300
#   Batch 10/38, Loss: 0.0152
#   Batch 20/38, Loss: 0.0161
#   Batch 30/38, Loss: 0.0164
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000156.pth
# Deleted old checkpoint: epoch_000154.pth
# Epoch [157/300], Train Loss: 0.0160, Val Loss: 0.0149
# Starting epoch 158/300
#   Batch 10/38, Loss: 0.0169
#   Batch 20/38, Loss: 0.0140
#   Batch 30/38, Loss: 0.0140
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000157.pth
# Deleted old checkpoint: epoch_000155.pth
# Epoch [158/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 159/300
#   Batch 10/38, Loss: 0.0168
#   Batch 20/38, Loss: 0.0151
#   Batch 30/38, Loss: 0.0165
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000158.pth
# Deleted old checkpoint: epoch_000156.pth
# Epoch [159/300], Train Loss: 0.0155, Val Loss: 0.0149
# Starting epoch 160/300
#   Batch 10/38, Loss: 0.0135
#   Batch 20/38, Loss: 0.0139
#   Batch 30/38, Loss: 0.0160
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000159.pth
# Deleted old checkpoint: epoch_000157.pth
# Epoch [160/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 161/300
#   Batch 10/38, Loss: 0.0127
#   Batch 20/38, Loss: 0.0250
#   Batch 30/38, Loss: 0.0139
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000160.pth
# Deleted old checkpoint: epoch_000158.pth
# Epoch [161/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 162/300
#   Batch 10/38, Loss: 0.0137
#   Batch 20/38, Loss: 0.0187
#   Batch 30/38, Loss: 0.0158
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000161.pth
# Deleted old checkpoint: epoch_000159.pth
# Epoch [162/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 163/300
#   Batch 10/38, Loss: 0.0184
#   Batch 20/38, Loss: 0.0149
#   Batch 30/38, Loss: 0.0141
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000162.pth
# Deleted old checkpoint: epoch_000160.pth
# Epoch [163/300], Train Loss: 0.0159, Val Loss: 0.0149
# Starting epoch 164/300
#   Batch 10/38, Loss: 0.0137
#   Batch 20/38, Loss: 0.0158
#   Batch 30/38, Loss: 0.0171
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000163.pth
# Deleted old checkpoint: epoch_000161.pth
# Epoch [164/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 165/300
#   Batch 10/38, Loss: 0.0147
#   Batch 20/38, Loss: 0.0095
#   Batch 30/38, Loss: 0.0155
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000164.pth
# Deleted old checkpoint: epoch_000162.pth
# Epoch [165/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 166/300
#   Batch 10/38, Loss: 0.0135
#   Batch 20/38, Loss: 0.0122
#   Batch 30/38, Loss: 0.0155
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000165.pth
# Deleted old checkpoint: epoch_000163.pth
# Epoch [166/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 167/300
#   Batch 10/38, Loss: 0.0151
#   Batch 20/38, Loss: 0.0167
#   Batch 30/38, Loss: 0.0166
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000166.pth
# Deleted old checkpoint: epoch_000164.pth
# Epoch [167/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 168/300
#   Batch 10/38, Loss: 0.0151
#   Batch 20/38, Loss: 0.0151
#   Batch 30/38, Loss: 0.0167
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000167.pth
# Deleted old checkpoint: epoch_000165.pth
# Epoch [168/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 169/300
#   Batch 10/38, Loss: 0.0157
#   Batch 20/38, Loss: 0.0161
#   Batch 30/38, Loss: 0.0126
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000168.pth
# Deleted old checkpoint: epoch_000166.pth
# Epoch [169/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 170/300
#   Batch 10/38, Loss: 0.0144
#   Batch 20/38, Loss: 0.0182
#   Batch 30/38, Loss: 0.0117
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000169.pth
# Deleted old checkpoint: epoch_000167.pth
# Epoch [170/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 171/300
#   Batch 10/38, Loss: 0.0213
#   Batch 20/38, Loss: 0.0161
#   Batch 30/38, Loss: 0.0121
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000170.pth
# Deleted old checkpoint: epoch_000168.pth
# Epoch [171/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 172/300
#   Batch 10/38, Loss: 0.0167
#   Batch 20/38, Loss: 0.0136
#   Batch 30/38, Loss: 0.0185
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000171.pth
# Deleted old checkpoint: epoch_000169.pth
# Epoch [172/300], Train Loss: 0.0155, Val Loss: 0.0149
# Starting epoch 173/300
#   Batch 10/38, Loss: 0.0204
#   Batch 20/38, Loss: 0.0186
#   Batch 30/38, Loss: 0.0146
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000172.pth
# Deleted old checkpoint: epoch_000170.pth
# Epoch [173/300], Train Loss: 0.0155, Val Loss: 0.0149
# Starting epoch 174/300
#   Batch 10/38, Loss: 0.0166
#   Batch 20/38, Loss: 0.0152
#   Batch 30/38, Loss: 0.0166
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000173.pth
# Deleted old checkpoint: epoch_000171.pth
# Epoch [174/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 175/300
#   Batch 10/38, Loss: 0.0146
#   Batch 20/38, Loss: 0.0149
#   Batch 30/38, Loss: 0.0167
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000174.pth
# Deleted old checkpoint: epoch_000172.pth
# Epoch [175/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 176/300
#   Batch 10/38, Loss: 0.0153
#   Batch 20/38, Loss: 0.0184
#   Batch 30/38, Loss: 0.0170
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000175.pth
# Deleted old checkpoint: epoch_000173.pth
# Epoch [176/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 177/300
#   Batch 10/38, Loss: 0.0179
#   Batch 20/38, Loss: 0.0158
#   Batch 30/38, Loss: 0.0150
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000176.pth
# Deleted old checkpoint: epoch_000174.pth
# Epoch [177/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 178/300
#   Batch 10/38, Loss: 0.0164
#   Batch 20/38, Loss: 0.0155
#   Batch 30/38, Loss: 0.0138
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000177.pth
# Deleted old checkpoint: epoch_000175.pth
# Epoch [178/300], Train Loss: 0.0154, Val Loss: 0.0149
# Starting epoch 179/300
#   Batch 10/38, Loss: 0.0172
#   Batch 20/38, Loss: 0.0116
#   Batch 30/38, Loss: 0.0177
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000178.pth
# Deleted old checkpoint: epoch_000176.pth
# Epoch [179/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 180/300
#   Batch 10/38, Loss: 0.0169
#   Batch 20/38, Loss: 0.0147
#   Batch 30/38, Loss: 0.0166
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000179.pth
# Deleted old checkpoint: epoch_000177.pth
# Epoch [180/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 181/300
#   Batch 10/38, Loss: 0.0160
#   Batch 20/38, Loss: 0.0150
#   Batch 30/38, Loss: 0.0163
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000180.pth
# Deleted old checkpoint: epoch_000178.pth
# Epoch [181/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 182/300
#   Batch 10/38, Loss: 0.0142
#   Batch 20/38, Loss: 0.0155
#   Batch 30/38, Loss: 0.0193
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000181.pth
# Deleted old checkpoint: epoch_000179.pth
# Epoch [182/300], Train Loss: 0.0155, Val Loss: 0.0149
# Starting epoch 183/300
#   Batch 10/38, Loss: 0.0156
#   Batch 20/38, Loss: 0.0167
#   Batch 30/38, Loss: 0.0138
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000182.pth
# Deleted old checkpoint: epoch_000180.pth
# Epoch [183/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 184/300
#   Batch 10/38, Loss: 0.0139
#   Batch 20/38, Loss: 0.0212
#   Batch 30/38, Loss: 0.0181
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000183.pth
# Deleted old checkpoint: epoch_000181.pth
# Epoch [184/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 185/300
#   Batch 10/38, Loss: 0.0206
#   Batch 20/38, Loss: 0.0146
#   Batch 30/38, Loss: 0.0143
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000184.pth
# Deleted old checkpoint: epoch_000182.pth
# Epoch [185/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 186/300
#   Batch 10/38, Loss: 0.0190
#   Batch 20/38, Loss: 0.0163
#   Batch 30/38, Loss: 0.0137
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000185.pth
# Deleted old checkpoint: epoch_000183.pth
# Epoch [186/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 187/300
#   Batch 10/38, Loss: 0.0164
#   Batch 20/38, Loss: 0.0159
#   Batch 30/38, Loss: 0.0147
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000186.pth
# Deleted old checkpoint: epoch_000184.pth
# Epoch [187/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 188/300
#   Batch 10/38, Loss: 0.0149
#   Batch 20/38, Loss: 0.0125
#   Batch 30/38, Loss: 0.0136
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000187.pth
# Deleted old checkpoint: epoch_000185.pth
# Epoch [188/300], Train Loss: 0.0155, Val Loss: 0.0149
# Starting epoch 189/300
#   Batch 10/38, Loss: 0.0201
#   Batch 20/38, Loss: 0.0140
#   Batch 30/38, Loss: 0.0186
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000188.pth
# Deleted old checkpoint: epoch_000186.pth
# Epoch [189/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 190/300
#   Batch 10/38, Loss: 0.0127
#   Batch 20/38, Loss: 0.0168
#   Batch 30/38, Loss: 0.0172
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000189.pth
# Deleted old checkpoint: epoch_000187.pth
# Epoch [190/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 191/300
#   Batch 10/38, Loss: 0.0172
#   Batch 20/38, Loss: 0.0141
#   Batch 30/38, Loss: 0.0147
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000190.pth
# Deleted old checkpoint: epoch_000188.pth
# Epoch [191/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 192/300
#   Batch 10/38, Loss: 0.0145
#   Batch 20/38, Loss: 0.0194
#   Batch 30/38, Loss: 0.0187
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000191.pth
# Deleted old checkpoint: epoch_000189.pth
# Epoch [192/300], Train Loss: 0.0155, Val Loss: 0.0149
# Starting epoch 193/300
#   Batch 10/38, Loss: 0.0168
#   Batch 20/38, Loss: 0.0147
#   Batch 30/38, Loss: 0.0190
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000192.pth
# Deleted old checkpoint: epoch_000190.pth
# Epoch [193/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 194/300
#   Batch 10/38, Loss: 0.0163
#   Batch 20/38, Loss: 0.0166
#   Batch 30/38, Loss: 0.0125
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000193.pth
# Deleted old checkpoint: epoch_000191.pth
# Epoch [194/300], Train Loss: 0.0155, Val Loss: 0.0149
# Starting epoch 195/300
#   Batch 10/38, Loss: 0.0141
#   Batch 20/38, Loss: 0.0150
#   Batch 30/38, Loss: 0.0153
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000194.pth
# Deleted old checkpoint: epoch_000192.pth
# Epoch [195/300], Train Loss: 0.0155, Val Loss: 0.0149
# Starting epoch 196/300
#   Batch 10/38, Loss: 0.0173
#   Batch 20/38, Loss: 0.0153
#   Batch 30/38, Loss: 0.0128
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000195.pth
# Deleted old checkpoint: epoch_000193.pth
# Epoch [196/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 197/300
#   Batch 10/38, Loss: 0.0165
#   Batch 20/38, Loss: 0.0161
#   Batch 30/38, Loss: 0.0150
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000196.pth
# Deleted old checkpoint: epoch_000194.pth
# Epoch [197/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 198/300
#   Batch 10/38, Loss: 0.0163
#   Batch 20/38, Loss: 0.0159
#   Batch 30/38, Loss: 0.0152
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000197.pth
# Deleted old checkpoint: epoch_000195.pth
# Epoch [198/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 199/300
#   Batch 10/38, Loss: 0.0151
#   Batch 20/38, Loss: 0.0169
#   Batch 30/38, Loss: 0.0162
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000198.pth
# Deleted old checkpoint: epoch_000196.pth
# Epoch [199/300], Train Loss: 0.0159, Val Loss: 0.0149
# Starting epoch 200/300
#   Batch 10/38, Loss: 0.0127
#   Batch 20/38, Loss: 0.0135
#   Batch 30/38, Loss: 0.0200
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000199.pth
# Deleted old checkpoint: epoch_000197.pth
# Epoch [200/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 201/300
#   Batch 10/38, Loss: 0.0184
#   Batch 20/38, Loss: 0.0152
#   Batch 30/38, Loss: 0.0149
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000200.pth
# Deleted old checkpoint: epoch_000198.pth
# Epoch [201/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 202/300
#   Batch 10/38, Loss: 0.0154
#   Batch 20/38, Loss: 0.0155
#   Batch 30/38, Loss: 0.0156
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000201.pth
# Deleted old checkpoint: epoch_000199.pth
# Epoch [202/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 203/300
#   Batch 10/38, Loss: 0.0140
#   Batch 20/38, Loss: 0.0166
#   Batch 30/38, Loss: 0.0172
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000202.pth
# Deleted old checkpoint: epoch_000200.pth
# Epoch [203/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 204/300
#   Batch 10/38, Loss: 0.0158
#   Batch 20/38, Loss: 0.0159
#   Batch 30/38, Loss: 0.0123
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000203.pth
# Deleted old checkpoint: epoch_000201.pth
# Epoch [204/300], Train Loss: 0.0155, Val Loss: 0.0149
# Starting epoch 205/300
#   Batch 10/38, Loss: 0.0165
#   Batch 20/38, Loss: 0.0175
#   Batch 30/38, Loss: 0.0137
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000204.pth
# ...
# Deleted old checkpoint: epoch_000263.pth
# Epoch [266/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 267/300
#   Batch 10/38, Loss: 0.0152
#   Batch 20/38, Loss: 0.0173
#   Batch 30/38, Loss: 0.0178
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000266.pth
# Deleted old checkpoint: epoch_000264.pth
# Epoch [267/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 268/300
#   Batch 10/38, Loss: 0.0134
#   Batch 20/38, Loss: 0.0163
#   Batch 30/38, Loss: 0.0137
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000267.pth
# Deleted old checkpoint: epoch_000265.pth
# Epoch [268/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 269/300
#   Batch 10/38, Loss: 0.0143
#   Batch 20/38, Loss: 0.0150
#   Batch 30/38, Loss: 0.0164
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000268.pth
# Deleted old checkpoint: epoch_000266.pth
# Epoch [269/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 270/300
#   Batch 10/38, Loss: 0.0134
#   Batch 20/38, Loss: 0.0147
#   Batch 30/38, Loss: 0.0155
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000269.pth
# Deleted old checkpoint: epoch_000267.pth
# Epoch [270/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 271/300
#   Batch 10/38, Loss: 0.0139
#   Batch 20/38, Loss: 0.0169
#   Batch 30/38, Loss: 0.0170
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000270.pth
# Deleted old checkpoint: epoch_000268.pth
# Epoch [271/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 272/300
#   Batch 10/38, Loss: 0.0175
#   Batch 20/38, Loss: 0.0154
#   Batch 30/38, Loss: 0.0162
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000271.pth
# Deleted old checkpoint: epoch_000269.pth
# Epoch [272/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 273/300
#   Batch 10/38, Loss: 0.0179
#   Batch 20/38, Loss: 0.0158
#   Batch 30/38, Loss: 0.0129
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000272.pth
# Deleted old checkpoint: epoch_000270.pth
# Epoch [273/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 274/300
#   Batch 10/38, Loss: 0.0152
#   Batch 20/38, Loss: 0.0166
#   Batch 30/38, Loss: 0.0177
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000273.pth
# Deleted old checkpoint: epoch_000271.pth
# Epoch [274/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 275/300
#   Batch 10/38, Loss: 0.0202
#   Batch 20/38, Loss: 0.0151
#   Batch 30/38, Loss: 0.0203
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000274.pth
# Deleted old checkpoint: epoch_000272.pth
# Epoch [275/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 276/300
#   Batch 10/38, Loss: 0.0152
#   Batch 20/38, Loss: 0.0116
#   Batch 30/38, Loss: 0.0132
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000275.pth
# Deleted old checkpoint: epoch_000273.pth
# Epoch [276/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 277/300
#   Batch 10/38, Loss: 0.0116
#   Batch 20/38, Loss: 0.0151
#   Batch 30/38, Loss: 0.0185
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000276.pth
# Deleted old checkpoint: epoch_000274.pth
# Epoch [277/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 278/300
#   Batch 10/38, Loss: 0.0167
#   Batch 20/38, Loss: 0.0151
#   Batch 30/38, Loss: 0.0160
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000277.pth
# Deleted old checkpoint: epoch_000275.pth
# Epoch [278/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 279/300
#   Batch 10/38, Loss: 0.0160
#   Batch 20/38, Loss: 0.0121
#   Batch 30/38, Loss: 0.0172
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000278.pth
# Deleted old checkpoint: epoch_000276.pth
# Epoch [279/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 280/300
#   Batch 10/38, Loss: 0.0139
#   Batch 20/38, Loss: 0.0160
#   Batch 30/38, Loss: 0.0160
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000279.pth
# Deleted old checkpoint: epoch_000277.pth
# Epoch [280/300], Train Loss: 0.0159, Val Loss: 0.0149
# Starting epoch 281/300
#   Batch 10/38, Loss: 0.0132
#   Batch 20/38, Loss: 0.0151
#   Batch 30/38, Loss: 0.0138
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000280.pth
# Deleted old checkpoint: epoch_000278.pth
# Epoch [281/300], Train Loss: 0.0155, Val Loss: 0.0149
# Starting epoch 282/300
#   Batch 10/38, Loss: 0.0203
#   Batch 20/38, Loss: 0.0136
#   Batch 30/38, Loss: 0.0136
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000281.pth
# Deleted old checkpoint: epoch_000279.pth
# Epoch [282/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 283/300
#   Batch 10/38, Loss: 0.0166
#   Batch 20/38, Loss: 0.0199
#   Batch 30/38, Loss: 0.0152
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000282.pth
# Deleted old checkpoint: epoch_000280.pth
# Epoch [283/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 284/300
#   Batch 10/38, Loss: 0.0143
#   Batch 20/38, Loss: 0.0138
#   Batch 30/38, Loss: 0.0138
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000283.pth
# Deleted old checkpoint: epoch_000281.pth
# Epoch [284/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 285/300
#   Batch 10/38, Loss: 0.0134
#   Batch 20/38, Loss: 0.0129
#   Batch 30/38, Loss: 0.0171
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000284.pth
# Deleted old checkpoint: epoch_000282.pth
# Epoch [285/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 286/300
#   Batch 10/38, Loss: 0.0150
#   Batch 20/38, Loss: 0.0130
#   Batch 30/38, Loss: 0.0162
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000285.pth
# Deleted old checkpoint: epoch_000283.pth
# Epoch [286/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 287/300
#   Batch 10/38, Loss: 0.0142
#   Batch 20/38, Loss: 0.0117
#   Batch 30/38, Loss: 0.0216
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000286.pth
# Deleted old checkpoint: epoch_000284.pth
# Epoch [287/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 288/300
#   Batch 10/38, Loss: 0.0147
#   Batch 20/38, Loss: 0.0122
#   Batch 30/38, Loss: 0.0163
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000287.pth
# Deleted old checkpoint: epoch_000285.pth
# Epoch [288/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 289/300
#   Batch 10/38, Loss: 0.0133
#   Batch 20/38, Loss: 0.0191
#   Batch 30/38, Loss: 0.0163
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000288.pth
# Deleted old checkpoint: epoch_000286.pth
# Epoch [289/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 290/300
#   Batch 10/38, Loss: 0.0189
#   Batch 20/38, Loss: 0.0190
#   Batch 30/38, Loss: 0.0158
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000289.pth
# Deleted old checkpoint: epoch_000287.pth
# Epoch [290/300], Train Loss: 0.0155, Val Loss: 0.0149
# Starting epoch 291/300
#   Batch 10/38, Loss: 0.0158
#   Batch 20/38, Loss: 0.0164
#   Batch 30/38, Loss: 0.0153
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000290.pth
# Deleted old checkpoint: epoch_000288.pth
# Epoch [291/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 292/300
#   Batch 10/38, Loss: 0.0139
#   Batch 20/38, Loss: 0.0169
#   Batch 30/38, Loss: 0.0146
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000291.pth
# Deleted old checkpoint: epoch_000289.pth
# Epoch [292/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 293/300
#   Batch 10/38, Loss: 0.0175
#   Batch 20/38, Loss: 0.0158
#   Batch 30/38, Loss: 0.0144
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000292.pth
# Deleted old checkpoint: epoch_000290.pth
# Epoch [293/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 294/300
#   Batch 10/38, Loss: 0.0149
#   Batch 20/38, Loss: 0.0144
#   Batch 30/38, Loss: 0.0117
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000293.pth
# Deleted old checkpoint: epoch_000291.pth
# Epoch [294/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 295/300
#   Batch 10/38, Loss: 0.0170
#   Batch 20/38, Loss: 0.0147
#   Batch 30/38, Loss: 0.0140
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000294.pth
# Deleted old checkpoint: epoch_000292.pth
# Epoch [295/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 296/300
#   Batch 10/38, Loss: 0.0191
#   Batch 20/38, Loss: 0.0150
#   Batch 30/38, Loss: 0.0148
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000295.pth
# Deleted old checkpoint: epoch_000293.pth
# Epoch [296/300], Train Loss: 0.0156, Val Loss: 0.0149
# Starting epoch 297/300
#   Batch 10/38, Loss: 0.0170
#   Batch 20/38, Loss: 0.0173
#   Batch 30/38, Loss: 0.0139
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000296.pth
# Deleted old checkpoint: epoch_000294.pth
# Epoch [297/300], Train Loss: 0.0158, Val Loss: 0.0149
# Starting epoch 298/300
#   Batch 10/38, Loss: 0.0162
#   Batch 20/38, Loss: 0.0138
#   Batch 30/38, Loss: 0.0173
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000297.pth
# Deleted old checkpoint: epoch_000295.pth
# Epoch [298/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 299/300
#   Batch 10/38, Loss: 0.0162
#   Batch 20/38, Loss: 0.0135
#   Batch 30/38, Loss: 0.0174
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000298.pth
# Deleted old checkpoint: epoch_000296.pth
# Epoch [299/300], Train Loss: 0.0157, Val Loss: 0.0149
# Starting epoch 300/300
#   Batch 10/38, Loss: 0.0197
#   Batch 20/38, Loss: 0.0128
#   Batch 30/38, Loss: 0.0163
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/checkpoints/epoch_000299.pth
# Deleted old checkpoint: epoch_000297.pth
# Epoch [300/300], Train Loss: 0.0157, Val Loss: 0.0149
# Training complete. Best validation loss: 0.0145
# /tmp/ipykernel_677713/2315922466.py:162: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_checkpoint = torch.load(best_model_path, map_location=device)
# Loaded best model from epoch 81 with loss 0.0145
# Final model saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_cnn_multiview/vgg19_256_multiview/proprioception_mlp.pth
#
# Testing multi-view CNN model on random examples:
# ------------------------------------------------------------
# Example 1:
#   View 1 shape: torch.Size([1, 3, 256, 256])
#   View 2 shape: torch.Size([1, 3, 256, 256])
#   Latent shape: torch.Size([1, 256])
#   Target position: [0.2709384  0.65022457 0.29910257 0.48742312 0.73724264 0.23908657]
#   Predicted position: [0.3599518  0.67725927 0.22808337 0.43484753 0.441798   0.47818425]
#   Mean squared error: 0.026820
#
# Example 2:
#   View 1 shape: torch.Size([1, 3, 256, 256])
#   View 2 shape: torch.Size([1, 3, 256, 256])
#   Latent shape: torch.Size([1, 256])
#   Target position: [0.8884927  0.59413934 0.27151477 0.6784262  0.7311824  0.17874762]
#   Predicted position: [0.84530586 0.6002718  0.2861594  0.6194405  0.7351022  0.17558551]
#   Mean squared error: 0.000937
#
# Example 3:
#   View 1 shape: torch.Size([1, 3, 256, 256])
#   View 2 shape: torch.Size([1, 3, 256, 256])
#   Latent shape: torch.Size([1, 256])
#   Target position: [0.1777816  0.4163223  0.17788464 0.9417194  0.22777468 0.51498747]
#   Predicted position: [0.3662761  0.3777942  0.34544235 0.6760705  0.38779846 0.41114888]
#   Mean squared error: 0.028675
#
# Example 4:
#   View 1 shape: torch.Size([1, 3, 256, 256])
#   View 2 shape: torch.Size([1, 3, 256, 256])
#   Latent shape: torch.Size([1, 256])
#   Target position: [0.5656677  0.44342497 0.29473698 0.0784262  0.8890381  0.17874762]
#   Predicted position: [0.6777571  0.42750037 0.3247731  0.14115925 0.5849862  0.23519489]
#   Mean squared error: 0.018882
#
# Example 5:
#   View 1 shape: torch.Size([1, 3, 256, 256])
#   View 2 shape: torch.Size([1, 3, 256, 256])
#   Latent shape: torch.Size([1, 256])
#   Target position: [0.5091441  0.7655679  0.01863111 0.43201151 0.081244   0.53402126]
#   Predicted position: [0.35542598 0.6900212  0.16296439 0.3498813  0.4207127  0.40485525]
#   Mean squared error: 0.031473

# %%
# Run additional tests
print("\nRunning additional model tests...\n")
test_model_encoding(model, view_inputs_validation, device)
test_process_file(model, view_inputs_validation)
visualize_model_predictions(model, view_inputs_validation, targets_validation, device)
test_model_robustness(model, view_inputs_validation, targets_validation, device)
# Out:
# Running additional model tests...
#
#
# Testing model encoding functionality:
# ------------------------------------------------------------
#
# Sample 1:
#   View 1 features shape: torch.Size([1, 32768])
#   View 2 features shape: torch.Size([1, 32768])
#   Concatenated features shape: torch.Size([1, 65536])
#   Latent representation shape: torch.Size([1, 256])
#   Model output shape: torch.Size([1, 6])
#   Proprioceptor output shape: torch.Size([1, 6])
#   Forward pass matches proprioceptor: True
#   All shape assertions passed!
#
# Sample 2:
#   View 1 features shape: torch.Size([1, 32768])
#   View 2 features shape: torch.Size([1, 32768])
#   Concatenated features shape: torch.Size([1, 65536])
#   Latent representation shape: torch.Size([1, 256])
#   Model output shape: torch.Size([1, 6])
#   Proprioceptor output shape: torch.Size([1, 6])
#   Forward pass matches proprioceptor: True
#   All shape assertions passed!
#
# Sample 3:
#   View 1 features shape: torch.Size([1, 32768])
#   View 2 features shape: torch.Size([1, 32768])
#   Concatenated features shape: torch.Size([1, 65536])
#   Latent representation shape: torch.Size([1, 256])
#   Model output shape: torch.Size([1, 6])
#   Proprioceptor output shape: torch.Size([1, 6])
#   Forward pass matches proprioceptor: True
#   All shape assertions passed!
#
# Testing process_file method with view caching:
# ------------------------------------------------------------
#
# Test 1:
#   Processed with camera 0, latent shape: (256,)
#   Processed with camera 1, latent shape: (256,)
#   Processed with camera 0 (new timestep), latent shape: (256,)
#   Processed with camera 1 (new timestep), latent shape: (256,)
#   All shape assertions passed!
#
# Test 2:
#   Processed with camera 0, latent shape: (256,)
#   Processed with camera 1, latent shape: (256,)
#   Processed with camera 0 (new timestep), latent shape: (256,)
#   Processed with camera 1 (new timestep), latent shape: (256,)
#   All shape assertions passed!
#
# Test 3:
#   Processed with camera 0, latent shape: (256,)
#   Processed with camera 1, latent shape: (256,)
#   Processed with camera 0 (new timestep), latent shape: (256,)
#   Processed with camera 1 (new timestep), latent shape: (256,)
#   All shape assertions passed!
#
# Comparing model predictions with ground truth:
# ------------------------------------------------------------
#
# Sample 1:
#   Field                 | Ground Truth | Prediction  | Difference
#   ---------------------|--------------|-------------|------------
#   height               |       0.7623 |      0.7430 |    -0.0193
#   distance             |       0.6025 |      0.5632 |    -0.0392
#   heading              |       0.8442 |      0.7362 |    -0.1080
#   wrist_angle          |       0.5499 |      0.5276 |    -0.0223
#   wrist_rotation       |       0.3902 |      0.6567 |     0.2665
#   gripper              |       0.4410 |      0.5312 |     0.0902
#   MSE: 0.015535, MAE: 0.090911
#
# Sample 2:
#   Field                 | Ground Truth | Prediction  | Difference
#   ---------------------|--------------|-------------|------------
#   height               |       0.5500 |      0.6707 |     0.1207
#   distance             |       0.5429 |      0.5400 |    -0.0029
#   heading              |       0.3500 |      0.3722 |     0.0222
#   wrist_angle          |       0.2000 |      0.3275 |     0.1275
#   wrist_rotation       |       0.7178 |      0.6027 |    -0.1151
#   gripper              |       0.1000 |      0.3161 |     0.2161
#   MSE: 0.015206, MAE: 0.100719
#
# Sample 3:
#   Field                 | Ground Truth | Prediction  | Difference
#   ---------------------|--------------|-------------|------------
#   height               |       0.6640 |      0.7184 |     0.0544
#   distance             |       0.4863 |      0.4541 |    -0.0322
#   heading              |       0.4855 |      0.3682 |    -0.1173
#   wrist_angle          |       0.8081 |      0.7809 |    -0.0272
#   wrist_rotation       |       0.6624 |      0.6181 |    -0.0443
#   gripper              |       0.0242 |      0.2216 |     0.1973
#   MSE: 0.009899, MAE: 0.078775
#
# Sample 4:
#   Field                 | Ground Truth | Prediction  | Difference
#   ---------------------|--------------|-------------|------------
#   height               |       0.1614 |      0.1945 |     0.0331
#   distance             |       0.6405 |      0.7170 |     0.0765
#   heading              |       0.4405 |      0.4668 |     0.0263
#   wrist_angle          |       0.4866 |      0.4334 |    -0.0532
#   wrist_rotation       |       0.5216 |      0.4052 |    -0.1164
#   gripper              |       0.8230 |      0.8842 |     0.0613
#   MSE: 0.004629, MAE: 0.061128
#
# Sample 5:
#   Field                 | Ground Truth | Prediction  | Difference
#   ---------------------|--------------|-------------|------------
#   height               |       0.8807 |      0.6997 |    -0.1809
#   distance             |       0.2044 |      0.3346 |     0.1302
#   heading              |       0.1539 |      0.2827 |     0.1289
#   wrist_angle          |       0.3201 |      0.4070 |     0.0869
#   wrist_rotation       |       0.6896 |      0.5946 |    -0.0950
#   gripper              |       0.1817 |      0.1660 |    -0.0157
#   MSE: 0.013855, MAE: 0.106272
#
# Average errors across samples:
#   Mean Squared Error: 0.011825
#   Mean Absolute Error: 0.087561
#
# Testing model robustness to imperfect views:
# ------------------------------------------------------------
#
# Sample 1:
#   Clean views MSE: 0.012604
#   Noisy view MSE: 0.022922
#   Duplicate view MSE: 0.055862
#   Noise impact: 81.85% increase in error
#   Missing view impact: 343.20% increase in error
#
# Sample 2:
#   Clean views MSE: 0.011392
#   Noisy view MSE: 0.024642
#   Duplicate view MSE: 0.037509
#   Noise impact: 116.31% increase in error
#   Missing view impact: 229.26% increase in error
#
# Sample 3:
#   Clean views MSE: 0.012804
#   Noisy view MSE: 0.030597
#   Duplicate view MSE: 0.033667
#   Noise impact: 138.97% increase in error
#   Missing view impact: 162.95% increase in error

# %%
print("\nMulti-view CNN training and testing complete!")
print(f"Model type: {exp['model']}")
print(f"Number of views: {num_views}")
print(f"Latent space dimension: {exp['latent_size']}")
print(f"Output dimension (robot DOF): {exp['output_size']}")
print(f"Use the appropriate MultiView sensor processing class to load and use this model for inference.")
# Out:
# Multi-view CNN training and testing complete!
# Model type: VGG19ProprioTunedRegression_multiview
# Number of views: 2
# Latent space dimension: 256
# Output dimension (robot DOF): 6
# Use the appropriate MultiView sensor processing class to load and use this model for inference.
