# %% [markdown]
# # Train a proprioception-tuned Multi-View Vision Transformer (ViT)
# We create a sensor processing model using multiple Vision Transformer (ViT) based visual encoders
# finetuned with proprioception.
# We start with pretrained ViT models, then train them to:
# 1. Create a meaningful 128-dimensional latent representation from multiple camera views
# 2. Learn to map this representation to robot positions (proprioception)
#  The sensor processing object associated with the trained model is in sensorprocessing/sp_vit_multiview.py

# %%
import sys
sys.path.append("..")

from exp_run_config import Config
Config.PROJECTNAME = "BerryPicker"

import pathlib
import torch
import torch.nn as nn
from torchvision import models, transforms
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np

from demonstration.demonstration_helper import BCDemonstration
from sensorprocessing.sp_vit_multiview import MultiViewVitSensorProcessing
from robot.al5d_position_controller import RobotPosition

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# %%
# The experiment/run we are going to run: the specified model will be created
experiment = "sensorprocessing_propriotuned_Vit_multiview"


# Other possible configurations:

#concat_proj
# run = "vit_base_multiview"  # ViT Base
run = "vit_large_multiview" # ViT Large
# run = "vit_huge_multiview" # ViT Huge

##  indiv_proj
# run = "vit_base_multiview_indiv_proj"  # ViT Base_indiv_proj
# run = "vit_large_multiview_indiv_proj" # ViT Large_indiv_proj
# run = "vit_huge_multiview_indiv_proj" # ViT Huge


##  attention
# run = "vit_base_multiview_attention"  # ViT Base_attention
# run = "vit_large_multiview_attention" # ViT Large_attention
# run = "vit_huge_multiview_attention" # ViT Huge_attention

##  weighted_sum
# run = "vit_base_multiview_weighted_sum"  # ViT Base_weighted_sum
# run = "vit_large_multiview_weighted_sum" # ViT Large_weighted_sum
# run = "vit_huge_multiview_weighted_sum" # ViT Huge_weighted_sum

##  gated
# run = "vit_base_multiview_gated"  # ViT Base_gated
# run = "vit_large_multiview_gated" # ViT Large_gated
# run = "vit_huge_multiview_gated" # ViT Huge_gated

exp = Config().get_experiment(experiment, run)
# Out:
# Loading pointer config file: /home/ssheikholeslami/.config/BerryPicker/mainsettings.yaml
# Loading machine-specific config file: /home/ssheikholeslami/SaharaBerryPickerData/settings-sahara.yaml
# No system dependent experiment file
#  /home/ssheikholeslami/SaharaBerryPickerData/experiments-Config/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_sysdep.yaml,
#  that is ok, proceeding.
# Configuration for experiment: sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview successfully loaded

# %%
# Create output directory if it doesn't exist
data_dir = pathlib.Path(exp["data_dir"])
data_dir.mkdir(parents=True, exist_ok=True)
print(f"Data directory: {data_dir}")
# Out:
# Data directory: /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview

# %% [markdown]
# ### Create regression training data (image to proprioception)
# The training data (XX, Y) is all the 2-view pictures from a demonstration with the corresponding proprioception data.

# %%
def load_multiview_images_as_proprioception_training(task, proprioception_input_file, proprioception_target_file):
    """Loads all the images of a task from multiple camera views, and processes it as two tensors
    as input and target data for proprioception training.

    Caches the processed results into the input and target file pointed in the config.
    Remove those files to recalculate.
    """
    retval = {}
    if proprioception_input_file.exists():
        print(f"Loading cached data from {proprioception_input_file}")
        retval["view_inputs"] = torch.load(proprioception_input_file, weights_only=True)
        retval["targets"] = torch.load(proprioception_target_file, weights_only=True)
    else:
        demos_dir = pathlib.Path(Config()["demos"]["directory"])
        task_dir = pathlib.Path(demos_dir, "demos", task)

        # Lists to store multi-view images and targets
        view_lists = {}  # Dictionary to organize views by camera
        targetlist = []
        num_views = exp.get("num_views", 2)

        print(f"Loading demonstrations from {task_dir}")
        for demo_dir in task_dir.iterdir():
            if not demo_dir.is_dir():
                continue

            print(f"Processing demonstration: {demo_dir.name}")
            # Create BCDemonstration with multi-camera support
            bcd = BCDemonstration(
                demo_dir,
                sensorprocessor=None,
                cameras=None  # This will detect all available cameras
            )

            # Initialize view lists if not already done
            if not view_lists:
                for camera in bcd.cameras:
                    view_lists[camera] = []

            # Process each timestep
            for i in range(bcd.trim_from, bcd.trim_to):
                # Get all images for this timestep
                all_images = bcd.get_all_images(i)

                # If we don't have all required views, skip this timestep
                if len(all_images) < num_views:
                    print(f"  Skipping timestep {i} - only {len(all_images)}/{num_views} views available")
                    continue

                # Collect images from each camera
                for camera, (sensor_readings, _) in all_images.items():
                    if camera in view_lists:
                        view_lists[camera].append(sensor_readings[0])

                # Get the robot action for this timestep
                a = bcd.get_a(i)
                rp = RobotPosition.from_vector(a)
                anorm = rp.to_normalized_vector()
                targetlist.append(torch.from_numpy(anorm))

        # Ensure we have the same number of frames for each view
        min_frames = min(len(view_list) for view_list in view_lists.values())
        if min_frames < len(targetlist):
            print(f"Truncating dataset to {min_frames} frames (from {len(targetlist)})")
            targetlist = targetlist[:min_frames]
            for camera in view_lists:
                view_lists[camera] = view_lists[camera][:min_frames]

        # Stack tensors for each view
        view_tensors = []
        for camera in sorted(view_lists.keys())[:num_views]:  # Take only the required number of views
            view_tensors.append(torch.stack(view_lists[camera]))

        # Create multi-view input tensor [num_samples, num_views, C, H, W]
        retval["view_inputs"] = view_tensors
        retval["targets"] = torch.stack(targetlist)

        # Save processed data
        torch.save(retval["view_inputs"], proprioception_input_file)
        torch.save(retval["targets"], proprioception_target_file)
        print(f"Saved {len(targetlist)} training examples with {num_views} views each")

    # Separate the training and validation data
    length = len(retval["targets"])
    rows = torch.randperm(length)

    # Shuffle targets
    shuffled_targets = retval["targets"][rows]

    # Shuffle each view input using the same row indices
    shuffled_view_inputs = []
    for view_tensor in retval["view_inputs"]:
        shuffled_view_inputs.append(view_tensor[rows])

    # Split into training (67%) and validation (33%) sets
    training_size = int(length * 0.67)

    # Training data
    retval["view_inputs_training"] = [view[:training_size] for view in shuffled_view_inputs]
    retval["targets_training"] = shuffled_targets[:training_size]

    # Validation data
    retval["view_inputs_validation"] = [view[training_size:] for view in shuffled_view_inputs]
    retval["targets_validation"] = shuffled_targets[training_size:]

    print(f"Created {training_size} training examples and {length - training_size} validation examples")
    return retval

# %%
# Load the training data
task = exp["proprioception_training_task"]
proprioception_input_file = pathlib.Path(exp["data_dir"], exp["proprioception_input_file"])
proprioception_target_file = pathlib.Path(exp["data_dir"], exp["proprioception_target_file"])

tr = load_multiview_images_as_proprioception_training(task, proprioception_input_file, proprioception_target_file)
view_inputs_training = tr["view_inputs_training"]
targets_training = tr["targets_training"]
view_inputs_validation = tr["view_inputs_validation"]
targets_validation = tr["targets_validation"]
# Out:
# Loading cached data from /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview/train_inputs.pt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       3 proprioception_input_file = pathlib.Path(exp["data_dir"], exp["proprioception_input_file"])
#       4 proprioception_target_file = pathlib.Path(exp["data_dir"], exp["proprioception_target_file"])
# ----> 6 tr = load_multiview_images_as_proprioception_training(task, proprioception_input_file, proprioception_target_file)
#       7 view_inputs_training = tr["view_inputs_training"]
#       8 targets_training = tr["targets_training"]
#
# Cell In[4], line 11, in load_multiview_images_as_proprioception_training(task, proprioception_input_file, proprioception_target_file)
#       9 if proprioception_input_file.exists():
#      10     print(f"Loading cached data from {proprioception_input_file}")
# ---> 11     retval["view_inputs"] = torch.load(proprioception_input_file, weights_only=True)
#      12     retval["targets"] = torch.load(proprioception_target_file, weights_only=True)
#      13 else:
#
# File /apps/anaconda/anaconda-2023.09/lib/python3.11/site-packages/torch/serialization.py:1351, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1349 if weights_only:
#    1350     try:
# -> 1351         return _load(
#    1352             opened_zipfile,
#    1353             map_location,
#    1354             _weights_only_unpickler,
#    1355             overall_storage=overall_storage,
#    1356             **pickle_load_args,
#    1357         )
#    1358     except pickle.UnpicklingError as e:
#    1359         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#
# File /apps/anaconda/anaconda-2023.09/lib/python3.11/site-packages/torch/serialization.py:1848, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1846 global _serialization_tls
#    1847 _serialization_tls.map_location = map_location
# -> 1848 result = unpickler.load()
#    1849 _serialization_tls.map_location = None
#    1851 torch._utils._validate_loaded_sparse_tensors()
#
# File /apps/anaconda/anaconda-2023.09/lib/python3.11/site-packages/torch/_weights_only_unpickler.py:385, in Unpickler.load(self)
#     377     if (
#     378         type(pid) is tuple
#     379         and len(pid) > 0
#     380         and torch.serialization._maybe_decode_ascii(pid[0]) != "storage"
#     381     ):
#     382         raise UnpicklingError(
#     383             f"Only persistent_load of storage is allowed, but got {pid[0]}"
#     384         )
# --> 385     self.append(self.persistent_load(pid))
#     386 elif key[0] in [BINGET[0], LONG_BINGET[0]]:
#     387     idx = (read(1) if key[0] == BINGET[0] else unpack("<I", read(4)))[0]
#
# File /apps/anaconda/anaconda-2023.09/lib/python3.11/site-packages/torch/serialization.py:1812, in _load.<locals>.persistent_load(saved_id)
#    1810 else:
#    1811     nbytes = numel * torch._utils._element_size(dtype)
# -> 1812     typed_storage = load_tensor(
#    1813         dtype, nbytes, key, _maybe_decode_ascii(location)
#    1814     )
#    1816 return typed_storage
#
# File /apps/anaconda/anaconda-2023.09/lib/python3.11/site-packages/torch/serialization.py:1772, in _load.<locals>.load_tensor(dtype, numel, key, location)
#    1769     storage = overall_storage[storage_offset : storage_offset + numel]
#    1770 else:
#    1771     storage = (
# -> 1772         zip_file.get_storage_from_record(name, numel, torch.UntypedStorage)
#    1773         ._typed_storage()
#    1774         ._untyped_storage
#    1775     )
#    1776 # swap here if byteswapping is needed
#    1777 if byteorderdata is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Create the multi-view ViT model

# %%
# Create the multi-view ViT model
sp = MultiViewVitSensorProcessing(exp, device)
model = sp.enc  # Get the actual encoder model for training

print("Model created successfully")

try:
    params = model.parameters()
    print("Parameters accessed successfully")
    param_count = sum(p.numel() for p in params)
    print(f"Total parameters: {param_count}")
except Exception as e:
    print(f"Error accessing parameters: {e}")

# Select loss function
loss_type = exp.get('loss', 'MSELoss')
if loss_type == 'MSELoss':
    criterion = nn.MSELoss()
elif loss_type == 'L1Loss':
    criterion = nn.L1Loss()
else:
    criterion = nn.MSELoss()  # Default to MSE

# Set up optimizer with appropriate learning rate and weight decay
optimizer = optim.Adam(
    model.parameters(),
    lr=exp.get('learning_rate', 0.001),
    weight_decay=exp.get('weight_decay', 0.01)
)

# Optional learning rate scheduler
lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=3, verbose=True
)
# Out:
# Initializing Multi-View ViT Sensor Processing:
#   Model: vit_l_16
#   Number of views: 2
#   Fusion type: gated
#   Latent dimension: 128
#   Image size: 224x224
# Using 2 x vit_l_16 with output dimension 1024
# Created gated fusion network
# Created proprioceptor: 128 → 64 → 64 → 6
# Feature extractors frozen. Projection and proprioceptor layers are trainable.
# Warning: Model file /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/proprioception_mlp.pth does not exist. Using untrained model.
# Model created successfully
# Parameters accessed successfully
# Total parameters: 607803144
# /apps/anaconda/anaconda-2023.09/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %% [markdown]
# ### Custom dataset for multi-view data

# %%
class MultiViewDataset(torch.utils.data.Dataset):
    def __init__(self, view_inputs, targets):
        self.view_inputs = view_inputs  # List of tensors, one per view
        self.targets = targets
        self.num_samples = len(targets)

    def __len__(self):
        return self.num_samples

    def __getitem__(self, idx):
        # Get corresponding sample from each view
        views = [view[idx] for view in self.view_inputs]
        target = self.targets[idx]
        return views, target

# %%
# Create DataLoaders for batching
batch_size = exp.get('batch_size', 32)
train_dataset = MultiViewDataset(view_inputs_training, targets_training)
test_dataset = MultiViewDataset(view_inputs_validation, targets_validation)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
def train_and_save_multiview_proprioception_model(model, criterion, optimizer, modelfile,
                                                device="cpu", epochs=20, scheduler=None,
                                                log_interval=1):
    """Trains and saves the multi-view ViT proprioception model with checkpoint support

    Args:
        model: Multi-view ViT model with proprioception
        criterion: Loss function
        optimizer: Optimizer
        modelfile: Path to save the final model
        device: Training device (cpu/cuda)
        epochs: Number of training epochs
        scheduler: Optional learning rate scheduler
        log_interval: How often to print logs
    """
    # Create checkpoint directory
    checkpoint_dir = modelfile.parent / "checkpoints"
    checkpoint_dir.mkdir(exist_ok=True)

    # Maximum number of checkpoints to keep (excluding the best model)
    max_checkpoints = 2

    # Ensure model is on the right device
    model = model.to(device)
    criterion = criterion.to(device)

    # Function to extract epoch number from checkpoint file
    def get_epoch_number(checkpoint_file):
        try:
            # Use a more robust approach to extract epoch number
            # Format: epoch_XXXX.pth where XXXX is the epoch number
            filename = checkpoint_file.stem
            parts = filename.split('_')
            if len(parts) >= 2:
                return int(parts[1])  # Get the number after "epoch_"
            return 0
        except:
            return 0

    # Keep track of the best validation loss
    best_val_loss = float('inf')
    start_epoch = 0

    # Check for existing checkpoints to resume from
    checkpoint_files = list(checkpoint_dir.glob("epoch_*.pth"))
    if checkpoint_files:
        # Sort by epoch number for more reliable ordering
        checkpoint_files.sort(key=get_epoch_number)

        # Get the most recent checkpoint
        latest_checkpoint = checkpoint_files[-1]
        epoch_num = get_epoch_number(latest_checkpoint)

        print(f"Found checkpoint from epoch {epoch_num}. Resuming training...")

        # Load checkpoint
        checkpoint = torch.load(latest_checkpoint, map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        start_epoch = checkpoint['epoch'] + 1
        best_val_loss = checkpoint.get('best_val_loss', float('inf'))

        print(f"Resuming from epoch {start_epoch}/{epochs} with best validation loss: {best_val_loss:.4f}")

    # Function to clean up old checkpoints
    def cleanup_old_checkpoints():
        # Get all epoch checkpoint files
        checkpoint_files = list(checkpoint_dir.glob("epoch_*.pth"))

        # Sort by actual epoch number, not just filename
        checkpoint_files.sort(key=get_epoch_number)

        if len(checkpoint_files) > max_checkpoints:
            files_to_delete = checkpoint_files[:-max_checkpoints]
            for file_path in files_to_delete:
                try:
                    file_path.unlink()
                    print(f"Deleted old checkpoint: {file_path.name}")
                except Exception as e:
                    print(f"Failed to delete {file_path.name}: {e}")

    # Training loop
    for epoch in range(start_epoch, epochs):
        print(f"Starting epoch {epoch+1}/{epochs}")

        # Training phase
        model.train()
        total_loss = 0
        for batch_idx, (batch_views, batch_y) in enumerate(train_loader):
            # Move views and targets to device
            batch_views = [view.to(device) for view in batch_views]
            batch_y = batch_y.to(device)

            # Forward pass through the full model (including proprioceptor)
            predictions = model.forward(batch_views)
            loss = criterion(predictions, batch_y)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

            # Print progress every few batches
            if (batch_idx + 1) % 10 == 0:
                print(f"  Batch {batch_idx+1}/{len(train_loader)}, Loss: {loss.item():.4f}")

        avg_train_loss = total_loss / len(train_loader)

        # Validation phase
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for batch_views, batch_y in test_loader:
                # Move views and targets to device
                batch_views = [view.to(device) for view in batch_views]
                batch_y = batch_y.to(device)

                predictions = model(batch_views)
                loss = criterion(predictions, batch_y)
                val_loss += loss.item()

        avg_val_loss = val_loss / len(test_loader)

        # Update learning rate if scheduler is provided
        if scheduler is not None:
            scheduler.step(avg_val_loss)

        # Save checkpoint for this epoch - using formatted epoch numbers for reliable sorting
        checkpoint_path = checkpoint_dir / f"epoch_{epoch:06d}.pth"
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'train_loss': avg_train_loss,
            'val_loss': avg_val_loss,
            'best_val_loss': best_val_loss
        }, checkpoint_path)
        print(f"Checkpoint saved to {checkpoint_path}")

        # Clean up old checkpoints to save space
        cleanup_old_checkpoints()

        # Save the best model separately
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_model_path = checkpoint_dir / "best_model.pth"
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'train_loss': avg_train_loss,
                'val_loss': avg_val_loss,
                'best_val_loss': best_val_loss
            }, best_model_path)
            print(f"  New best model saved with validation loss: {best_val_loss:.4f}")

        # Log progress
        if (epoch + 1) % log_interval == 0:
            print(f'Epoch [{epoch+1}/{epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}')

    # Training completed successfully
    print(f"Training complete. Best validation loss: {best_val_loss:.4f}")

    # Load the best model for final save
    best_model_path = checkpoint_dir / "best_model.pth"
    if best_model_path.exists():
        best_checkpoint = torch.load(best_model_path, map_location=device)
        model.load_state_dict(best_checkpoint['model_state_dict'])
        print(f"Loaded best model from epoch {best_checkpoint['epoch']+1} with loss {best_checkpoint['val_loss']:.4f}")

    # Save to final model file only after completing all epochs
    torch.save(model.state_dict(), modelfile)
    print(f"Final model saved to {modelfile}")

    return model


# Set up model file path and epochs
modelfile = pathlib.Path(exp["data_dir"], exp["proprioception_mlp_model_file"])
epochs = exp.get("epochs", 20)

# First check for existing final model
if modelfile.exists() and exp.get("reload_existing_model", True):
    print(f"Loading existing final model from {modelfile}")
    model.load_state_dict(torch.load(modelfile, map_location=device))

    # Evaluate the loaded model
    model.eval()
    with torch.no_grad():
        val_loss = 0
        for batch_views, batch_y in test_loader:
            # Move views and targets to device
            batch_views = [view.to(device) for view in batch_views]
            batch_y = batch_y.to(device)

            predictions = model(batch_views)
            loss = criterion(predictions, batch_y)
            val_loss += loss.item()

        avg_val_loss = val_loss / len(test_loader)
        print(f"Loaded model validation loss: {avg_val_loss:.4f}")
else:
    # Check for checkpoints to resume from, otherwise start fresh training
    checkpoint_dir = modelfile.parent / "checkpoints"
    checkpoint_dir.mkdir(exist_ok=True)

    # Use the get_epoch_number function for reliable sorting
    def get_epoch_number(checkpoint_file):
        try:
            filename = checkpoint_file.stem
            parts = filename.split('_')
            if len(parts) >= 2:
                return int(parts[1])
            return 0
        except:
            return 0

    checkpoint_files = list(checkpoint_dir.glob("epoch_*.pth"))
    if checkpoint_files:
        # Sort by epoch number
        checkpoint_files.sort(key=get_epoch_number)
        latest_epoch = get_epoch_number(checkpoint_files[-1])
        print(f"Found checkpoints up to epoch {latest_epoch}. Will resume training from last checkpoint.")
    else:
        print(f"Starting new training for {epochs} epochs")

    # Train the model with checkpoint support
    model = train_and_save_multiview_proprioception_model(
        model, criterion, optimizer, modelfile,
        device=device, epochs=epochs, scheduler=lr_scheduler
    )
# Out:
# Starting new training for 300 epochs
# Starting epoch 1/300
#   Batch 10/37, Loss: 0.3241
#   Batch 20/37, Loss: 0.2129
#   Batch 30/37, Loss: 0.1449
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000000.pth
#   New best model saved with validation loss: 0.1244
# Epoch [1/300], Train Loss: 0.2276, Val Loss: 0.1244
# Starting epoch 2/300
#   Batch 10/37, Loss: 0.0622
#   Batch 20/37, Loss: 0.0477
#   Batch 30/37, Loss: 0.0425
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000001.pth
#   New best model saved with validation loss: 0.0407
# Epoch [2/300], Train Loss: 0.0595, Val Loss: 0.0407
# Starting epoch 3/300
#   Batch 10/37, Loss: 0.0371
#   Batch 20/37, Loss: 0.0294
#   Batch 30/37, Loss: 0.0306
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000002.pth
# Deleted old checkpoint: epoch_000000.pth
#   New best model saved with validation loss: 0.0328
# Epoch [3/300], Train Loss: 0.0332, Val Loss: 0.0328
# Starting epoch 4/300
#   Batch 10/37, Loss: 0.0256
#   Batch 20/37, Loss: 0.0261
#   Batch 30/37, Loss: 0.0253
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000003.pth
# Deleted old checkpoint: epoch_000001.pth
#   New best model saved with validation loss: 0.0288
# Epoch [4/300], Train Loss: 0.0264, Val Loss: 0.0288
# Starting epoch 5/300
#   Batch 10/37, Loss: 0.0233
#   Batch 20/37, Loss: 0.0236
#   Batch 30/37, Loss: 0.0233
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000004.pth
# Deleted old checkpoint: epoch_000002.pth
#   New best model saved with validation loss: 0.0224
# Epoch [5/300], Train Loss: 0.0227, Val Loss: 0.0224
# Starting epoch 6/300
#   Batch 10/37, Loss: 0.0176
#   Batch 20/37, Loss: 0.0184
#   Batch 30/37, Loss: 0.0232
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000005.pth
# Deleted old checkpoint: epoch_000003.pth
#   New best model saved with validation loss: 0.0194
# Epoch [6/300], Train Loss: 0.0200, Val Loss: 0.0194
# Starting epoch 7/300
#   Batch 10/37, Loss: 0.0159
#   Batch 20/37, Loss: 0.0171
#   Batch 30/37, Loss: 0.0162
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000006.pth
# Deleted old checkpoint: epoch_000004.pth
#   New best model saved with validation loss: 0.0184
# Epoch [7/300], Train Loss: 0.0174, Val Loss: 0.0184
# Starting epoch 8/300
#   Batch 10/37, Loss: 0.0128
#   Batch 20/37, Loss: 0.0214
#   Batch 30/37, Loss: 0.0192
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000007.pth
# Deleted old checkpoint: epoch_000005.pth
# Epoch [8/300], Train Loss: 0.0184, Val Loss: 0.0317
# Starting epoch 9/300
#   Batch 10/37, Loss: 0.0164
#   Batch 20/37, Loss: 0.0253
#   Batch 30/37, Loss: 0.0346
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000008.pth
# Deleted old checkpoint: epoch_000006.pth
#   New best model saved with validation loss: 0.0172
# Epoch [9/300], Train Loss: 0.0175, Val Loss: 0.0172
# Starting epoch 10/300
#   Batch 10/37, Loss: 0.0127
#   Batch 20/37, Loss: 0.0143
#   Batch 30/37, Loss: 0.0158
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000009.pth
# Deleted old checkpoint: epoch_000007.pth
# Epoch [10/300], Train Loss: 0.0163, Val Loss: 0.0172
# Starting epoch 11/300
#   Batch 10/37, Loss: 0.0161
#   Batch 20/37, Loss: 0.0143
#   Batch 30/37, Loss: 0.0187
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000010.pth
# Deleted old checkpoint: epoch_000008.pth
# Epoch [11/300], Train Loss: 0.0158, Val Loss: 0.0177
# Starting epoch 12/300
#   Batch 10/37, Loss: 0.0231
#   Batch 20/37, Loss: 0.0157
#   Batch 30/37, Loss: 0.0187
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000011.pth
# Deleted old checkpoint: epoch_000009.pth
#   New best model saved with validation loss: 0.0145
# Epoch [12/300], Train Loss: 0.0152, Val Loss: 0.0145
# Starting epoch 13/300
#   Batch 10/37, Loss: 0.0100
#   Batch 20/37, Loss: 0.0124
#   Batch 30/37, Loss: 0.0106
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000012.pth
# Deleted old checkpoint: epoch_000010.pth
# Epoch [13/300], Train Loss: 0.0131, Val Loss: 0.0150
# Starting epoch 14/300
#   Batch 10/37, Loss: 0.0118
#   Batch 20/37, Loss: 0.0144
#   Batch 30/37, Loss: 0.0127
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000013.pth
# Deleted old checkpoint: epoch_000011.pth
# Epoch [14/300], Train Loss: 0.0125, Val Loss: 0.0147
# Starting epoch 15/300
#   Batch 10/37, Loss: 0.0159
#   Batch 20/37, Loss: 0.0112
#   Batch 30/37, Loss: 0.0117
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000014.pth
# Deleted old checkpoint: epoch_000012.pth
# Epoch [15/300], Train Loss: 0.0134, Val Loss: 0.0254
# Starting epoch 16/300
#   Batch 10/37, Loss: 0.0107
#   Batch 20/37, Loss: 0.0130
#   Batch 30/37, Loss: 0.0160
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000015.pth
# Deleted old checkpoint: epoch_000013.pth
# Epoch [16/300], Train Loss: 0.0132, Val Loss: 0.0150
# Starting epoch 17/300
#   Batch 10/37, Loss: 0.0136
#   Batch 20/37, Loss: 0.0112
#   Batch 30/37, Loss: 0.0101
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000016.pth
# Deleted old checkpoint: epoch_000014.pth
# Epoch [17/300], Train Loss: 0.0116, Val Loss: 0.0159
# Starting epoch 18/300
#   Batch 10/37, Loss: 0.0122
#   Batch 20/37, Loss: 0.0104
#   Batch 30/37, Loss: 0.0068
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000017.pth
# Deleted old checkpoint: epoch_000015.pth
#   New best model saved with validation loss: 0.0118
# Epoch [18/300], Train Loss: 0.0113, Val Loss: 0.0118
# Starting epoch 19/300
#   Batch 10/37, Loss: 0.0103
#   Batch 20/37, Loss: 0.0076
#   Batch 30/37, Loss: 0.0094
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000018.pth
# Deleted old checkpoint: epoch_000016.pth
# Epoch [19/300], Train Loss: 0.0105, Val Loss: 0.0136
# Starting epoch 20/300
#   Batch 10/37, Loss: 0.0115
#   Batch 20/37, Loss: 0.0104
#   Batch 30/37, Loss: 0.0110
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000019.pth
# Deleted old checkpoint: epoch_000017.pth
# Epoch [20/300], Train Loss: 0.0112, Val Loss: 0.0126
# Starting epoch 21/300
#   Batch 10/37, Loss: 0.0109
#   Batch 20/37, Loss: 0.0087
#   Batch 30/37, Loss: 0.0106
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000020.pth
# Deleted old checkpoint: epoch_000018.pth
# Epoch [21/300], Train Loss: 0.0106, Val Loss: 0.0120
# Starting epoch 22/300
#   Batch 10/37, Loss: 0.0102
#   Batch 20/37, Loss: 0.0186
#   Batch 30/37, Loss: 0.0102
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000021.pth
# Deleted old checkpoint: epoch_000019.pth
# Epoch [22/300], Train Loss: 0.0121, Val Loss: 0.0132
# Starting epoch 23/300
#   Batch 10/37, Loss: 0.0081
#   Batch 20/37, Loss: 0.0089
#   Batch 30/37, Loss: 0.0092
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000022.pth
# Deleted old checkpoint: epoch_000020.pth
#   New best model saved with validation loss: 0.0104
# Epoch [23/300], Train Loss: 0.0097, Val Loss: 0.0104
# Starting epoch 24/300
#   Batch 10/37, Loss: 0.0108
#   Batch 20/37, Loss: 0.0076
#   Batch 30/37, Loss: 0.0089
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000023.pth
# Deleted old checkpoint: epoch_000021.pth
# Epoch [24/300], Train Loss: 0.0081, Val Loss: 0.0114
# Starting epoch 25/300
#   Batch 10/37, Loss: 0.0101
#   Batch 20/37, Loss: 0.0075
#   Batch 30/37, Loss: 0.0095
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000024.pth
# Deleted old checkpoint: epoch_000022.pth
#   New best model saved with validation loss: 0.0098
# Epoch [25/300], Train Loss: 0.0083, Val Loss: 0.0098
# Starting epoch 26/300
#   Batch 10/37, Loss: 0.0063
#   Batch 20/37, Loss: 0.0080
#   Batch 30/37, Loss: 0.0057
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000025.pth
# Deleted old checkpoint: epoch_000023.pth
# Epoch [26/300], Train Loss: 0.0080, Val Loss: 0.0108
# Starting epoch 27/300
#   Batch 10/37, Loss: 0.0103
#   Batch 20/37, Loss: 0.0093
#   Batch 30/37, Loss: 0.0068
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000026.pth
# Deleted old checkpoint: epoch_000024.pth
# Epoch [27/300], Train Loss: 0.0084, Val Loss: 0.0109
# Starting epoch 28/300
#   Batch 10/37, Loss: 0.0115
#   Batch 20/37, Loss: 0.0069
#   Batch 30/37, Loss: 0.0106
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000027.pth
# Deleted old checkpoint: epoch_000025.pth
#   New best model saved with validation loss: 0.0097
# Epoch [28/300], Train Loss: 0.0092, Val Loss: 0.0097
# Starting epoch 29/300
#   Batch 10/37, Loss: 0.0071
#   Batch 20/37, Loss: 0.0102
#   Batch 30/37, Loss: 0.0066
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000028.pth
# Deleted old checkpoint: epoch_000026.pth
#   New best model saved with validation loss: 0.0095
# Epoch [29/300], Train Loss: 0.0084, Val Loss: 0.0095
# Starting epoch 30/300
#   Batch 10/37, Loss: 0.0069
#   Batch 20/37, Loss: 0.0078
#   Batch 30/37, Loss: 0.0070
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000029.pth
# Deleted old checkpoint: epoch_000027.pth
#   New best model saved with validation loss: 0.0093
# Epoch [30/300], Train Loss: 0.0081, Val Loss: 0.0093
# Starting epoch 31/300
#   Batch 10/37, Loss: 0.0063
#   Batch 20/37, Loss: 0.0078
#   Batch 30/37, Loss: 0.0085
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000030.pth
# Deleted old checkpoint: epoch_000028.pth
# Epoch [31/300], Train Loss: 0.0082, Val Loss: 0.0094
# Starting epoch 32/300
#   Batch 10/37, Loss: 0.0077
#   Batch 20/37, Loss: 0.0091
#   Batch 30/37, Loss: 0.0103
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000031.pth
# Deleted old checkpoint: epoch_000029.pth
# Epoch [32/300], Train Loss: 0.0087, Val Loss: 0.0119
# Starting epoch 33/300
#   Batch 10/37, Loss: 0.0084
#   Batch 20/37, Loss: 0.0106
#   Batch 30/37, Loss: 0.0090
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000032.pth
# Deleted old checkpoint: epoch_000030.pth
# Epoch [33/300], Train Loss: 0.0086, Val Loss: 0.0103
# Starting epoch 34/300
#   Batch 10/37, Loss: 0.0059
#   Batch 20/37, Loss: 0.0049
#   Batch 30/37, Loss: 0.0075
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000033.pth
# Deleted old checkpoint: epoch_000031.pth
# Epoch [34/300], Train Loss: 0.0083, Val Loss: 0.0100
# Starting epoch 35/300
#   Batch 10/37, Loss: 0.0076
#   Batch 20/37, Loss: 0.0046
#   Batch 30/37, Loss: 0.0045
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000034.pth
# Deleted old checkpoint: epoch_000032.pth
#   New best model saved with validation loss: 0.0087
# Epoch [35/300], Train Loss: 0.0070, Val Loss: 0.0087
# Starting epoch 36/300
#   Batch 10/37, Loss: 0.0069
#   Batch 20/37, Loss: 0.0062
#   Batch 30/37, Loss: 0.0061
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000035.pth
# Deleted old checkpoint: epoch_000033.pth
#   New best model saved with validation loss: 0.0084
# Epoch [36/300], Train Loss: 0.0073, Val Loss: 0.0084
# Starting epoch 37/300
#   Batch 10/37, Loss: 0.0085
#   Batch 20/37, Loss: 0.0058
#   Batch 30/37, Loss: 0.0049
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000036.pth
# Deleted old checkpoint: epoch_000034.pth
# Epoch [37/300], Train Loss: 0.0066, Val Loss: 0.0089
# Starting epoch 38/300
#   Batch 10/37, Loss: 0.0082
#   Batch 20/37, Loss: 0.0077
#   Batch 30/37, Loss: 0.0047
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000037.pth
# Deleted old checkpoint: epoch_000035.pth
#   New best model saved with validation loss: 0.0083
# Epoch [38/300], Train Loss: 0.0069, Val Loss: 0.0083
# Starting epoch 39/300
#   Batch 10/37, Loss: 0.0070
#   Batch 20/37, Loss: 0.0077
#   Batch 30/37, Loss: 0.0078
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000038.pth
# Deleted old checkpoint: epoch_000036.pth
# Epoch [39/300], Train Loss: 0.0073, Val Loss: 0.0089
# Starting epoch 40/300
#   Batch 10/37, Loss: 0.0074
#   Batch 20/37, Loss: 0.0065
#   Batch 30/37, Loss: 0.0081
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000039.pth
# Deleted old checkpoint: epoch_000037.pth
# Epoch [40/300], Train Loss: 0.0073, Val Loss: 0.0084
# Starting epoch 41/300
#   Batch 10/37, Loss: 0.0074
#   Batch 20/37, Loss: 0.0066
#   Batch 30/37, Loss: 0.0090
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000040.pth
# Deleted old checkpoint: epoch_000038.pth
# Epoch [41/300], Train Loss: 0.0076, Val Loss: 0.0087
# Starting epoch 42/300
#   Batch 10/37, Loss: 0.0078
#   Batch 20/37, Loss: 0.0054
#   Batch 30/37, Loss: 0.0062
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000041.pth
# Deleted old checkpoint: epoch_000039.pth
# Epoch [42/300], Train Loss: 0.0073, Val Loss: 0.0085
# Starting epoch 43/300
#   Batch 10/37, Loss: 0.0059
#   Batch 20/37, Loss: 0.0061
#   Batch 30/37, Loss: 0.0068
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000042.pth
# Deleted old checkpoint: epoch_000040.pth
#   New best model saved with validation loss: 0.0083
# Epoch [43/300], Train Loss: 0.0067, Val Loss: 0.0083
# Starting epoch 44/300
#   Batch 10/37, Loss: 0.0046
#   Batch 20/37, Loss: 0.0075
#   Batch 30/37, Loss: 0.0052
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000043.pth
# Deleted old checkpoint: epoch_000041.pth
# Epoch [44/300], Train Loss: 0.0068, Val Loss: 0.0084
# Starting epoch 45/300
#   Batch 10/37, Loss: 0.0055
#   Batch 20/37, Loss: 0.0057
#   Batch 30/37, Loss: 0.0045
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000044.pth
# Deleted old checkpoint: epoch_000042.pth
# Epoch [45/300], Train Loss: 0.0061, Val Loss: 0.0089
# Starting epoch 46/300
#   Batch 10/37, Loss: 0.0034
#   Batch 20/37, Loss: 0.0057
#   Batch 30/37, Loss: 0.0067
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000045.pth
# Deleted old checkpoint: epoch_000043.pth
# Epoch [46/300], Train Loss: 0.0064, Val Loss: 0.0085
# Starting epoch 47/300
#   Batch 10/37, Loss: 0.0053
#   Batch 20/37, Loss: 0.0074
#   Batch 30/37, Loss: 0.0074
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000046.pth
# Deleted old checkpoint: epoch_000044.pth
# Epoch [47/300], Train Loss: 0.0060, Val Loss: 0.0086
# Starting epoch 48/300
#   Batch 10/37, Loss: 0.0051
#   Batch 20/37, Loss: 0.0045
#   Batch 30/37, Loss: 0.0071
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000047.pth
# Deleted old checkpoint: epoch_000045.pth
#   New best model saved with validation loss: 0.0082
# Epoch [48/300], Train Loss: 0.0064, Val Loss: 0.0082
# Starting epoch 49/300
#   Batch 10/37, Loss: 0.0109
#   Batch 20/37, Loss: 0.0046
#   Batch 30/37, Loss: 0.0069
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000048.pth
# Deleted old checkpoint: epoch_000046.pth
# Epoch [49/300], Train Loss: 0.0065, Val Loss: 0.0084
# Starting epoch 50/300
#   Batch 10/37, Loss: 0.0063
#   Batch 20/37, Loss: 0.0051
#   Batch 30/37, Loss: 0.0086
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000049.pth
# Deleted old checkpoint: epoch_000047.pth
#   New best model saved with validation loss: 0.0080
# Epoch [50/300], Train Loss: 0.0062, Val Loss: 0.0080
# Starting epoch 51/300
#   Batch 10/37, Loss: 0.0087
#   Batch 20/37, Loss: 0.0030
#   Batch 30/37, Loss: 0.0046
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000050.pth
# Deleted old checkpoint: epoch_000048.pth
# Epoch [51/300], Train Loss: 0.0063, Val Loss: 0.0082
# Starting epoch 52/300
#   Batch 10/37, Loss: 0.0043
#   Batch 20/37, Loss: 0.0067
#   Batch 30/37, Loss: 0.0066
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000051.pth
# Deleted old checkpoint: epoch_000049.pth
# Epoch [52/300], Train Loss: 0.0059, Val Loss: 0.0081
# Starting epoch 53/300
#   Batch 10/37, Loss: 0.0052
#   Batch 20/37, Loss: 0.0053
#   Batch 30/37, Loss: 0.0096
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000052.pth
# Deleted old checkpoint: epoch_000050.pth
# Epoch [53/300], Train Loss: 0.0060, Val Loss: 0.0080
# Starting epoch 54/300
#   Batch 10/37, Loss: 0.0053
#   Batch 20/37, Loss: 0.0074
#   Batch 30/37, Loss: 0.0055
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000053.pth
# Deleted old checkpoint: epoch_000051.pth
# Epoch [54/300], Train Loss: 0.0059, Val Loss: 0.0084
# Starting epoch 55/300
#   Batch 10/37, Loss: 0.0075
#   Batch 20/37, Loss: 0.0059
#   Batch 30/37, Loss: 0.0085
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000054.pth
# Deleted old checkpoint: epoch_000052.pth
# Epoch [55/300], Train Loss: 0.0062, Val Loss: 0.0085
# Starting epoch 56/300
#   Batch 10/37, Loss: 0.0058
#   Batch 20/37, Loss: 0.0082
#   Batch 30/37, Loss: 0.0043
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000055.pth
# Deleted old checkpoint: epoch_000053.pth
# Epoch [56/300], Train Loss: 0.0058, Val Loss: 0.0081
# Starting epoch 57/300
#   Batch 10/37, Loss: 0.0110
#   Batch 20/37, Loss: 0.0054
#   Batch 30/37, Loss: 0.0067
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000056.pth
# Deleted old checkpoint: epoch_000054.pth
# Epoch [57/300], Train Loss: 0.0062, Val Loss: 0.0080
# Starting epoch 58/300
#   Batch 10/37, Loss: 0.0043
#   Batch 20/37, Loss: 0.0048
#   Batch 30/37, Loss: 0.0061
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000057.pth
# Deleted old checkpoint: epoch_000055.pth
# Epoch [58/300], Train Loss: 0.0057, Val Loss: 0.0081
# Starting epoch 59/300
#   Batch 10/37, Loss: 0.0060
#   Batch 20/37, Loss: 0.0040
#   Batch 30/37, Loss: 0.0051
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000058.pth
# Deleted old checkpoint: epoch_000056.pth
# Epoch [59/300], Train Loss: 0.0060, Val Loss: 0.0081
# Starting epoch 60/300
#   Batch 10/37, Loss: 0.0053
#   Batch 20/37, Loss: 0.0037
#   Batch 30/37, Loss: 0.0095
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000059.pth
# Deleted old checkpoint: epoch_000057.pth
# Epoch [60/300], Train Loss: 0.0060, Val Loss: 0.0081
# Starting epoch 61/300
#   Batch 10/37, Loss: 0.0048
#   Batch 20/37, Loss: 0.0069
#   Batch 30/37, Loss: 0.0067
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000060.pth
# Deleted old checkpoint: epoch_000058.pth
# Epoch [61/300], Train Loss: 0.0060, Val Loss: 0.0080
# Starting epoch 62/300
#   Batch 10/37, Loss: 0.0042
#   Batch 20/37, Loss: 0.0038
#   Batch 30/37, Loss: 0.0081
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000061.pth
# Deleted old checkpoint: epoch_000059.pth
# Epoch [62/300], Train Loss: 0.0062, Val Loss: 0.0081
# Starting epoch 63/300
#   Batch 10/37, Loss: 0.0063
#   Batch 20/37, Loss: 0.0045
#   Batch 30/37, Loss: 0.0057
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000062.pth
# Deleted old checkpoint: epoch_000060.pth
# Epoch [63/300], Train Loss: 0.0065, Val Loss: 0.0081
# Starting epoch 64/300
#   Batch 10/37, Loss: 0.0066
#   Batch 20/37, Loss: 0.0055
#   Batch 30/37, Loss: 0.0065
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000063.pth
# Deleted old checkpoint: epoch_000061.pth
# Epoch [64/300], Train Loss: 0.0060, Val Loss: 0.0080
# Starting epoch 65/300
#   Batch 10/37, Loss: 0.0040
#   Batch 20/37, Loss: 0.0055
#   Batch 30/37, Loss: 0.0045
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000064.pth
# Deleted old checkpoint: epoch_000062.pth
# Epoch [65/300], Train Loss: 0.0060, Val Loss: 0.0080
# Starting epoch 66/300
#   Batch 10/37, Loss: 0.0057
#   Batch 20/37, Loss: 0.0053
#   Batch 30/37, Loss: 0.0083
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000065.pth
# Deleted old checkpoint: epoch_000063.pth
#   New best model saved with validation loss: 0.0080
# Epoch [66/300], Train Loss: 0.0060, Val Loss: 0.0080
# Starting epoch 67/300
#   Batch 10/37, Loss: 0.0072
#   Batch 20/37, Loss: 0.0059
#   Batch 30/37, Loss: 0.0040
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000066.pth
# Deleted old checkpoint: epoch_000064.pth
#   New best model saved with validation loss: 0.0079
# Epoch [67/300], Train Loss: 0.0058, Val Loss: 0.0079
# Starting epoch 68/300
#   Batch 10/37, Loss: 0.0049
#   Batch 20/37, Loss: 0.0061
#   Batch 30/37, Loss: 0.0053
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000067.pth
# Deleted old checkpoint: epoch_000065.pth
#   New best model saved with validation loss: 0.0078
# Epoch [68/300], Train Loss: 0.0058, Val Loss: 0.0078
# Starting epoch 69/300
#   Batch 10/37, Loss: 0.0080
#   Batch 20/37, Loss: 0.0037
#   Batch 30/37, Loss: 0.0037
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000068.pth
# Deleted old checkpoint: epoch_000066.pth
# Epoch [69/300], Train Loss: 0.0060, Val Loss: 0.0080
# Starting epoch 70/300
#   Batch 10/37, Loss: 0.0047
#   Batch 20/37, Loss: 0.0057
#   Batch 30/37, Loss: 0.0057
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000069.pth
# Deleted old checkpoint: epoch_000067.pth
# Epoch [70/300], Train Loss: 0.0059, Val Loss: 0.0079
# Starting epoch 71/300
#   Batch 10/37, Loss: 0.0087
#   Batch 20/37, Loss: 0.0042
#   Batch 30/37, Loss: 0.0039
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000070.pth
# Deleted old checkpoint: epoch_000068.pth
# Epoch [71/300], Train Loss: 0.0059, Val Loss: 0.0079
# Starting epoch 72/300
#   Batch 10/37, Loss: 0.0050
#   Batch 20/37, Loss: 0.0045
#   Batch 30/37, Loss: 0.0055
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000071.pth
# Deleted old checkpoint: epoch_000069.pth
# Epoch [72/300], Train Loss: 0.0061, Val Loss: 0.0080
# Starting epoch 73/300
#   Batch 10/37, Loss: 0.0061
#   Batch 20/37, Loss: 0.0047
#   Batch 30/37, Loss: 0.0053
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000072.pth
# Deleted old checkpoint: epoch_000070.pth
# Epoch [73/300], Train Loss: 0.0058, Val Loss: 0.0080
# Starting epoch 74/300
#   Batch 10/37, Loss: 0.0088
#   Batch 20/37, Loss: 0.0045
#   Batch 30/37, Loss: 0.0039
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000073.pth
# Deleted old checkpoint: epoch_000071.pth
# Epoch [74/300], Train Loss: 0.0062, Val Loss: 0.0080
# Starting epoch 75/300
#   Batch 10/37, Loss: 0.0046
#   Batch 20/37, Loss: 0.0055
#   Batch 30/37, Loss: 0.0053
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000074.pth
# Deleted old checkpoint: epoch_000072.pth
# Epoch [75/300], Train Loss: 0.0057, Val Loss: 0.0080
# Starting epoch 76/300
#   Batch 10/37, Loss: 0.0043
#   Batch 20/37, Loss: 0.0037
#   Batch 30/37, Loss: 0.0079
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000075.pth
# Deleted old checkpoint: epoch_000073.pth
# Epoch [76/300], Train Loss: 0.0061, Val Loss: 0.0079
# Starting epoch 77/300
#   Batch 10/37, Loss: 0.0079
#   Batch 20/37, Loss: 0.0033
#   Batch 30/37, Loss: 0.0060
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000076.pth
# Deleted old checkpoint: epoch_000074.pth
# Epoch [77/300], Train Loss: 0.0056, Val Loss: 0.0079
# Starting epoch 78/300
#   Batch 10/37, Loss: 0.0077
#   Batch 20/37, Loss: 0.0073
#   Batch 30/37, Loss: 0.0062
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000077.pth
# Deleted old checkpoint: epoch_000075.pth
# Epoch [78/300], Train Loss: 0.0065, Val Loss: 0.0080
# Starting epoch 79/300
#   Batch 10/37, Loss: 0.0085
#   Batch 20/37, Loss: 0.0049
#   Batch 30/37, Loss: 0.0049
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000078.pth
# Deleted old checkpoint: epoch_000076.pth
# Epoch [79/300], Train Loss: 0.0061, Val Loss: 0.0080
# Starting epoch 80/300
#   Batch 10/37, Loss: 0.0168
#   Batch 20/37, Loss: 0.0061
#   Batch 30/37, Loss: 0.0044
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000079.pth
# Deleted old checkpoint: epoch_000077.pth
# Epoch [80/300], Train Loss: 0.0060, Val Loss: 0.0081
# Starting epoch 81/300
#   Batch 10/37, Loss: 0.0066
#   Batch 20/37, Loss: 0.0064
#   Batch 30/37, Loss: 0.0056
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000080.pth
# Deleted old checkpoint: epoch_000078.pth
# Epoch [81/300], Train Loss: 0.0057, Val Loss: 0.0082
# Starting epoch 82/300
#   Batch 10/37, Loss: 0.0047
#   Batch 20/37, Loss: 0.0052
#   Batch 30/37, Loss: 0.0067
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000081.pth
# Deleted old checkpoint: epoch_000079.pth
# Epoch [82/300], Train Loss: 0.0061, Val Loss: 0.0080
# Starting epoch 83/300
#   Batch 10/37, Loss: 0.0095
#   Batch 20/37, Loss: 0.0076
#   Batch 30/37, Loss: 0.0032
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000082.pth
# Deleted old checkpoint: epoch_000080.pth
# Epoch [83/300], Train Loss: 0.0058, Val Loss: 0.0081
# Starting epoch 84/300
#   Batch 10/37, Loss: 0.0066
#   Batch 20/37, Loss: 0.0065
#   Batch 30/37, Loss: 0.0056
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000083.pth
# Deleted old checkpoint: epoch_000081.pth
# Epoch [84/300], Train Loss: 0.0056, Val Loss: 0.0080
# Starting epoch 85/300
#   Batch 10/37, Loss: 0.0060
#   Batch 20/37, Loss: 0.0066
#   Batch 30/37, Loss: 0.0063
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000084.pth
# Deleted old checkpoint: epoch_000082.pth
# Epoch [85/300], Train Loss: 0.0054, Val Loss: 0.0081
# Starting epoch 86/300
#   Batch 10/37, Loss: 0.0049
#   Batch 20/37, Loss: 0.0061
#   Batch 30/37, Loss: 0.0055
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000085.pth
# Deleted old checkpoint: epoch_000083.pth
# Epoch [86/300], Train Loss: 0.0062, Val Loss: 0.0079
# Starting epoch 87/300
#   Batch 10/37, Loss: 0.0062
#   Batch 20/37, Loss: 0.0087
#   Batch 30/37, Loss: 0.0061
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000086.pth
# Deleted old checkpoint: epoch_000084.pth
# Epoch [87/300], Train Loss: 0.0058, Val Loss: 0.0078
# Starting epoch 88/300
#   Batch 10/37, Loss: 0.0047
#   Batch 20/37, Loss: 0.0048
#   Batch 30/37, Loss: 0.0044
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000087.pth
# Deleted old checkpoint: epoch_000085.pth
# Epoch [88/300], Train Loss: 0.0066, Val Loss: 0.0080
# Starting epoch 89/300
#   Batch 10/37, Loss: 0.0074
#   Batch 20/37, Loss: 0.0046
#   Batch 30/37, Loss: 0.0058
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000088.pth
# Deleted old checkpoint: epoch_000086.pth
# Epoch [89/300], Train Loss: 0.0058, Val Loss: 0.0081
# Starting epoch 90/300
#   Batch 10/37, Loss: 0.0073
#   Batch 20/37, Loss: 0.0068
#   Batch 30/37, Loss: 0.0070
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000089.pth
# Deleted old checkpoint: epoch_000087.pth
# Epoch [90/300], Train Loss: 0.0059, Val Loss: 0.0081
# Starting epoch 91/300
#   Batch 10/37, Loss: 0.0070
#   Batch 20/37, Loss: 0.0044
#   Batch 30/37, Loss: 0.0051
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000090.pth
# Deleted old checkpoint: epoch_000088.pth
# Epoch [91/300], Train Loss: 0.0058, Val Loss: 0.0082
# Starting epoch 92/300
#   Batch 10/37, Loss: 0.0074
#   Batch 20/37, Loss: 0.0049
#   Batch 30/37, Loss: 0.0096
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000091.pth
# Deleted old checkpoint: epoch_000089.pth
# Epoch [92/300], Train Loss: 0.0061, Val Loss: 0.0078
# Starting epoch 93/300
#   Batch 10/37, Loss: 0.0049
#   Batch 20/37, Loss: 0.0049
#   Batch 30/37, Loss: 0.0066
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000092.pth
# Deleted old checkpoint: epoch_000090.pth
# Epoch [93/300], Train Loss: 0.0060, Val Loss: 0.0079
# Starting epoch 94/300
#   Batch 10/37, Loss: 0.0052
#   Batch 20/37, Loss: 0.0056
#   Batch 30/37, Loss: 0.0059
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000093.pth
# Deleted old checkpoint: epoch_000091.pth
# Epoch [94/300], Train Loss: 0.0057, Val Loss: 0.0078
# Starting epoch 95/300
#   Batch 10/37, Loss: 0.0055
#   Batch 20/37, Loss: 0.0041
#   Batch 30/37, Loss: 0.0048
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000094.pth
# Deleted old checkpoint: epoch_000092.pth
# Epoch [95/300], Train Loss: 0.0058, Val Loss: 0.0079
# Starting epoch 96/300
#   Batch 10/37, Loss: 0.0049
#   Batch 20/37, Loss: 0.0058
#   Batch 30/37, Loss: 0.0042
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000095.pth
# Deleted old checkpoint: epoch_000093.pth
# Epoch [96/300], Train Loss: 0.0058, Val Loss: 0.0080
# Starting epoch 97/300
#   Batch 10/37, Loss: 0.0052
#   Batch 20/37, Loss: 0.0054
#   Batch 30/37, Loss: 0.0062
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000096.pth
# Deleted old checkpoint: epoch_000094.pth
# Epoch [97/300], Train Loss: 0.0062, Val Loss: 0.0079
# Starting epoch 98/300
#   Batch 10/37, Loss: 0.0065
#   Batch 20/37, Loss: 0.0112
#   Batch 30/37, Loss: 0.0063
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000097.pth
# Deleted old checkpoint: epoch_000095.pth
# Epoch [98/300], Train Loss: 0.0058, Val Loss: 0.0080
# Starting epoch 99/300
#   Batch 10/37, Loss: 0.0052
#   Batch 20/37, Loss: 0.0042
#   Batch 30/37, Loss: 0.0051
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000098.pth
# Deleted old checkpoint: epoch_000096.pth
# Epoch [99/300], Train Loss: 0.0057, Val Loss: 0.0081
# Starting epoch 100/300
#   Batch 10/37, Loss: 0.0052
#   Batch 20/37, Loss: 0.0051
#   Batch 30/37, Loss: 0.0031
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000099.pth
# Deleted old checkpoint: epoch_000097.pth
# Epoch [100/300], Train Loss: 0.0064, Val Loss: 0.0080
# Starting epoch 101/300
#   Batch 10/37, Loss: 0.0032
#   Batch 20/37, Loss: 0.0038
#   Batch 30/37, Loss: 0.0050
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000100.pth
# Deleted old checkpoint: epoch_000098.pth
# Epoch [101/300], Train Loss: 0.0055, Val Loss: 0.0080
# Starting epoch 102/300
#   Batch 10/37, Loss: 0.0059
#   Batch 20/37, Loss: 0.0046
#   Batch 30/37, Loss: 0.0050
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000101.pth
# Deleted old checkpoint: epoch_000099.pth
# Epoch [102/300], Train Loss: 0.0060, Val Loss: 0.0079
# Starting epoch 103/300
#   Batch 10/37, Loss: 0.0071
#   Batch 20/37, Loss: 0.0089
#   Batch 30/37, Loss: 0.0089
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000102.pth
# Deleted old checkpoint: epoch_000100.pth
# Epoch [103/300], Train Loss: 0.0061, Val Loss: 0.0082
# Starting epoch 104/300
#   Batch 10/37, Loss: 0.0052
#   Batch 20/37, Loss: 0.0071
#   Batch 30/37, Loss: 0.0045
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000103.pth
# Deleted old checkpoint: epoch_000101.pth
# Epoch [104/300], Train Loss: 0.0055, Val Loss: 0.0079
# Starting epoch 105/300
#   Batch 10/37, Loss: 0.0044
#   Batch 20/37, Loss: 0.0052
#   Batch 30/37, Loss: 0.0085
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000104.pth
# Deleted old checkpoint: epoch_000102.pth
# Epoch [105/300], Train Loss: 0.0057, Val Loss: 0.0080
# Starting epoch 106/300
#   Batch 10/37, Loss: 0.0053
#   Batch 20/37, Loss: 0.0061
#   Batch 30/37, Loss: 0.0124
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000105.pth
# Deleted old checkpoint: epoch_000103.pth
# Epoch [106/300], Train Loss: 0.0062, Val Loss: 0.0078
# Starting epoch 107/300
#   Batch 10/37, Loss: 0.0059
#   Batch 20/37, Loss: 0.0043
#   Batch 30/37, Loss: 0.0049
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000106.pth
# Deleted old checkpoint: epoch_000104.pth
# Epoch [107/300], Train Loss: 0.0061, Val Loss: 0.0082
# Starting epoch 108/300
#   Batch 10/37, Loss: 0.0077
#   Batch 20/37, Loss: 0.0044
#   Batch 30/37, Loss: 0.0058
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000107.pth
# Deleted old checkpoint: epoch_000105.pth
# Epoch [108/300], Train Loss: 0.0058, Val Loss: 0.0080
# Starting epoch 109/300
#   Batch 10/37, Loss: 0.0046
#   Batch 20/37, Loss: 0.0033
#   Batch 30/37, Loss: 0.0054
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000108.pth
# Deleted old checkpoint: epoch_000106.pth
# Epoch [109/300], Train Loss: 0.0055, Val Loss: 0.0080
# Starting epoch 110/300
#   Batch 10/37, Loss: 0.0092
#   Batch 20/37, Loss: 0.0059
#   Batch 30/37, Loss: 0.0041
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000109.pth
# Deleted old checkpoint: epoch_000107.pth
# Epoch [110/300], Train Loss: 0.0061, Val Loss: 0.0080
# Starting epoch 111/300
#   Batch 10/37, Loss: 0.0065
#   Batch 20/37, Loss: 0.0041
#   Batch 30/37, Loss: 0.0060
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000110.pth
# Deleted old checkpoint: epoch_000108.pth
# Epoch [111/300], Train Loss: 0.0060, Val Loss: 0.0080
# Starting epoch 112/300
#   Batch 10/37, Loss: 0.0052
#   Batch 20/37, Loss: 0.0054
#   Batch 30/37, Loss: 0.0077
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000111.pth
# Deleted old checkpoint: epoch_000109.pth
# Epoch [112/300], Train Loss: 0.0060, Val Loss: 0.0079
# Starting epoch 113/300
#   Batch 10/37, Loss: 0.0030
#   Batch 20/37, Loss: 0.0058
#   Batch 30/37, Loss: 0.0046
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000112.pth
# Deleted old checkpoint: epoch_000110.pth
# Epoch [113/300], Train Loss: 0.0058, Val Loss: 0.0080
# Starting epoch 114/300
#   Batch 10/37, Loss: 0.0062
#   Batch 20/37, Loss: 0.0050
#   Batch 30/37, Loss: 0.0071
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000113.pth
# Deleted old checkpoint: epoch_000111.pth
# Epoch [114/300], Train Loss: 0.0063, Val Loss: 0.0080
# Starting epoch 115/300
#   Batch 10/37, Loss: 0.0090
#   Batch 20/37, Loss: 0.0049
#   Batch 30/37, Loss: 0.0027
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000114.pth
# Deleted old checkpoint: epoch_000112.pth
# Epoch [115/300], Train Loss: 0.0057, Val Loss: 0.0082
# Starting epoch 116/300
#   Batch 10/37, Loss: 0.0059
#   Batch 20/37, Loss: 0.0038
#   Batch 30/37, Loss: 0.0059
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000115.pth
# Deleted old checkpoint: epoch_000113.pth
# Epoch [116/300], Train Loss: 0.0059, Val Loss: 0.0081
# Starting epoch 117/300
#   Batch 10/37, Loss: 0.0054
#   Batch 20/37, Loss: 0.0051
#   Batch 30/37, Loss: 0.0038
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000116.pth
# Deleted old checkpoint: epoch_000114.pth
# Epoch [117/300], Train Loss: 0.0056, Val Loss: 0.0081
# Starting epoch 118/300
#   Batch 10/37, Loss: 0.0052
#   Batch 20/37, Loss: 0.0040
#   Batch 30/37, Loss: 0.0034
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000117.pth
# Deleted old checkpoint: epoch_000115.pth
# Epoch [118/300], Train Loss: 0.0057, Val Loss: 0.0082
# Starting epoch 119/300
#   Batch 10/37, Loss: 0.0052
#   Batch 20/37, Loss: 0.0069
#   Batch 30/37, Loss: 0.0041
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000118.pth
# Deleted old checkpoint: epoch_000116.pth
# Epoch [119/300], Train Loss: 0.0056, Val Loss: 0.0080
# Starting epoch 120/300
#   Batch 10/37, Loss: 0.0049
#   Batch 20/37, Loss: 0.0057
#   Batch 30/37, Loss: 0.0046
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000119.pth
# Deleted old checkpoint: epoch_000117.pth
# Epoch [120/300], Train Loss: 0.0054, Val Loss: 0.0080
# Starting epoch 121/300
#   Batch 10/37, Loss: 0.0137
#   Batch 20/37, Loss: 0.0048
#   Batch 30/37, Loss: 0.0061
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000120.pth
# Deleted old checkpoint: epoch_000118.pth
# Epoch [121/300], Train Loss: 0.0062, Val Loss: 0.0081
# Starting epoch 122/300
#   Batch 10/37, Loss: 0.0064
#   Batch 20/37, Loss: 0.0075
#   Batch 30/37, Loss: 0.0040
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000121.pth
# Deleted old checkpoint: epoch_000119.pth
# Epoch [122/300], Train Loss: 0.0055, Val Loss: 0.0082
# Starting epoch 123/300
#   Batch 10/37, Loss: 0.0050
#   Batch 20/37, Loss: 0.0061
#   Batch 30/37, Loss: 0.0049
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000122.pth
# Deleted old checkpoint: epoch_000120.pth
# Epoch [123/300], Train Loss: 0.0063, Val Loss: 0.0080
# Starting epoch 124/300
#   Batch 10/37, Loss: 0.0077
#   Batch 20/37, Loss: 0.0064
#   Batch 30/37, Loss: 0.0041
# ...
# Deleted old checkpoint: epoch_000259.pth
# Epoch [262/300], Train Loss: 0.0061, Val Loss: 0.0080
# Starting epoch 263/300
#   Batch 10/37, Loss: 0.0044
#   Batch 20/37, Loss: 0.0036
#   Batch 30/37, Loss: 0.0069
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000262.pth
# Deleted old checkpoint: epoch_000260.pth
# Epoch [263/300], Train Loss: 0.0061, Val Loss: 0.0081
# Starting epoch 264/300
#   Batch 10/37, Loss: 0.0049
#   Batch 20/37, Loss: 0.0070
#   Batch 30/37, Loss: 0.0133
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000263.pth
# Deleted old checkpoint: epoch_000261.pth
# Epoch [264/300], Train Loss: 0.0062, Val Loss: 0.0081
# Starting epoch 265/300
#   Batch 10/37, Loss: 0.0044
#   Batch 20/37, Loss: 0.0063
#   Batch 30/37, Loss: 0.0060
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000264.pth
# Deleted old checkpoint: epoch_000262.pth
# Epoch [265/300], Train Loss: 0.0055, Val Loss: 0.0080
# Starting epoch 266/300
#   Batch 10/37, Loss: 0.0053
#   Batch 20/37, Loss: 0.0116
#   Batch 30/37, Loss: 0.0060
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000265.pth
# Deleted old checkpoint: epoch_000263.pth
# Epoch [266/300], Train Loss: 0.0061, Val Loss: 0.0079
# Starting epoch 267/300
#   Batch 10/37, Loss: 0.0057
#   Batch 20/37, Loss: 0.0034
#   Batch 30/37, Loss: 0.0088
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000266.pth
# Deleted old checkpoint: epoch_000264.pth
# Epoch [267/300], Train Loss: 0.0062, Val Loss: 0.0080
# Starting epoch 268/300
#   Batch 10/37, Loss: 0.0054
#   Batch 20/37, Loss: 0.0040
#   Batch 30/37, Loss: 0.0063
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000267.pth
# Deleted old checkpoint: epoch_000265.pth
# Epoch [268/300], Train Loss: 0.0057, Val Loss: 0.0082
# Starting epoch 269/300
#   Batch 10/37, Loss: 0.0076
#   Batch 20/37, Loss: 0.0049
#   Batch 30/37, Loss: 0.0076
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000268.pth
# Deleted old checkpoint: epoch_000266.pth
# Epoch [269/300], Train Loss: 0.0055, Val Loss: 0.0079
# Starting epoch 270/300
#   Batch 10/37, Loss: 0.0069
#   Batch 20/37, Loss: 0.0059
#   Batch 30/37, Loss: 0.0050
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000269.pth
# Deleted old checkpoint: epoch_000267.pth
# Epoch [270/300], Train Loss: 0.0057, Val Loss: 0.0080
# Starting epoch 271/300
#   Batch 10/37, Loss: 0.0041
#   Batch 20/37, Loss: 0.0047
#   Batch 30/37, Loss: 0.0050
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000270.pth
# Deleted old checkpoint: epoch_000268.pth
# Epoch [271/300], Train Loss: 0.0053, Val Loss: 0.0082
# Starting epoch 272/300
#   Batch 10/37, Loss: 0.0092
#   Batch 20/37, Loss: 0.0071
#   Batch 30/37, Loss: 0.0056
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000271.pth
# Deleted old checkpoint: epoch_000269.pth
# Epoch [272/300], Train Loss: 0.0056, Val Loss: 0.0082
# Starting epoch 273/300
#   Batch 10/37, Loss: 0.0054
#   Batch 20/37, Loss: 0.0087
#   Batch 30/37, Loss: 0.0061
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000272.pth
# Deleted old checkpoint: epoch_000270.pth
# Epoch [273/300], Train Loss: 0.0060, Val Loss: 0.0080
# Starting epoch 274/300
#   Batch 10/37, Loss: 0.0091
#   Batch 20/37, Loss: 0.0057
#   Batch 30/37, Loss: 0.0046
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000273.pth
# Deleted old checkpoint: epoch_000271.pth
# Epoch [274/300], Train Loss: 0.0059, Val Loss: 0.0078
# Starting epoch 275/300
#   Batch 10/37, Loss: 0.0045
#   Batch 20/37, Loss: 0.0047
#   Batch 30/37, Loss: 0.0034
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000274.pth
# Deleted old checkpoint: epoch_000272.pth
# Epoch [275/300], Train Loss: 0.0057, Val Loss: 0.0081
# Starting epoch 276/300
#   Batch 10/37, Loss: 0.0047
#   Batch 20/37, Loss: 0.0066
#   Batch 30/37, Loss: 0.0054
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000275.pth
# Deleted old checkpoint: epoch_000273.pth
# Epoch [276/300], Train Loss: 0.0057, Val Loss: 0.0083
# Starting epoch 277/300
#   Batch 10/37, Loss: 0.0094
#   Batch 20/37, Loss: 0.0036
#   Batch 30/37, Loss: 0.0069
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000276.pth
# Deleted old checkpoint: epoch_000274.pth
# Epoch [277/300], Train Loss: 0.0062, Val Loss: 0.0082
# Starting epoch 278/300
#   Batch 10/37, Loss: 0.0073
#   Batch 20/37, Loss: 0.0092
#   Batch 30/37, Loss: 0.0041
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000277.pth
# Deleted old checkpoint: epoch_000275.pth
# Epoch [278/300], Train Loss: 0.0058, Val Loss: 0.0080
# Starting epoch 279/300
#   Batch 10/37, Loss: 0.0046
#   Batch 20/37, Loss: 0.0032
#   Batch 30/37, Loss: 0.0048
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000278.pth
# Deleted old checkpoint: epoch_000276.pth
# Epoch [279/300], Train Loss: 0.0055, Val Loss: 0.0078
# Starting epoch 280/300
#   Batch 10/37, Loss: 0.0081
#   Batch 20/37, Loss: 0.0037
#   Batch 30/37, Loss: 0.0060
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000279.pth
# Deleted old checkpoint: epoch_000277.pth
# Epoch [280/300], Train Loss: 0.0059, Val Loss: 0.0079
# Starting epoch 281/300
#   Batch 10/37, Loss: 0.0063
#   Batch 20/37, Loss: 0.0083
#   Batch 30/37, Loss: 0.0046
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000280.pth
# Deleted old checkpoint: epoch_000278.pth
# Epoch [281/300], Train Loss: 0.0058, Val Loss: 0.0080
# Starting epoch 282/300
#   Batch 10/37, Loss: 0.0042
#   Batch 20/37, Loss: 0.0046
#   Batch 30/37, Loss: 0.0047
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000281.pth
# Deleted old checkpoint: epoch_000279.pth
# Epoch [282/300], Train Loss: 0.0053, Val Loss: 0.0080
# Starting epoch 283/300
#   Batch 10/37, Loss: 0.0057
#   Batch 20/37, Loss: 0.0082
#   Batch 30/37, Loss: 0.0097
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000282.pth
# Deleted old checkpoint: epoch_000280.pth
# Epoch [283/300], Train Loss: 0.0057, Val Loss: 0.0080
# Starting epoch 284/300
#   Batch 10/37, Loss: 0.0077
#   Batch 20/37, Loss: 0.0064
#   Batch 30/37, Loss: 0.0053
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000283.pth
# Deleted old checkpoint: epoch_000281.pth
# Epoch [284/300], Train Loss: 0.0057, Val Loss: 0.0079
# Starting epoch 285/300
#   Batch 10/37, Loss: 0.0051
#   Batch 20/37, Loss: 0.0054
#   Batch 30/37, Loss: 0.0049
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000284.pth
# Deleted old checkpoint: epoch_000282.pth
# Epoch [285/300], Train Loss: 0.0055, Val Loss: 0.0081
# Starting epoch 286/300
#   Batch 10/37, Loss: 0.0039
#   Batch 20/37, Loss: 0.0077
#   Batch 30/37, Loss: 0.0050
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000285.pth
# Deleted old checkpoint: epoch_000283.pth
# Epoch [286/300], Train Loss: 0.0058, Val Loss: 0.0081
# Starting epoch 287/300
#   Batch 10/37, Loss: 0.0072
#   Batch 20/37, Loss: 0.0078
#   Batch 30/37, Loss: 0.0060
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000286.pth
# Deleted old checkpoint: epoch_000284.pth
# Epoch [287/300], Train Loss: 0.0055, Val Loss: 0.0080
# Starting epoch 288/300
#   Batch 10/37, Loss: 0.0046
#   Batch 20/37, Loss: 0.0039
#   Batch 30/37, Loss: 0.0049
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000287.pth
# Deleted old checkpoint: epoch_000285.pth
# Epoch [288/300], Train Loss: 0.0060, Val Loss: 0.0082
# Starting epoch 289/300
#   Batch 10/37, Loss: 0.0054
#   Batch 20/37, Loss: 0.0086
#   Batch 30/37, Loss: 0.0074
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000288.pth
# Deleted old checkpoint: epoch_000286.pth
# Epoch [289/300], Train Loss: 0.0059, Val Loss: 0.0080
# Starting epoch 290/300
#   Batch 10/37, Loss: 0.0057
#   Batch 20/37, Loss: 0.0051
#   Batch 30/37, Loss: 0.0052
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000289.pth
# Deleted old checkpoint: epoch_000287.pth
# Epoch [290/300], Train Loss: 0.0056, Val Loss: 0.0078
# Starting epoch 291/300
#   Batch 10/37, Loss: 0.0047
#   Batch 20/37, Loss: 0.0081
#   Batch 30/37, Loss: 0.0085
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000290.pth
# Deleted old checkpoint: epoch_000288.pth
# Epoch [291/300], Train Loss: 0.0061, Val Loss: 0.0081
# Starting epoch 292/300
#   Batch 10/37, Loss: 0.0043
#   Batch 20/37, Loss: 0.0053
#   Batch 30/37, Loss: 0.0060
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000291.pth
# Deleted old checkpoint: epoch_000289.pth
# Epoch [292/300], Train Loss: 0.0058, Val Loss: 0.0081
# Starting epoch 293/300
#   Batch 10/37, Loss: 0.0043
#   Batch 20/37, Loss: 0.0044
#   Batch 30/37, Loss: 0.0033
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000292.pth
# Deleted old checkpoint: epoch_000290.pth
# Epoch [293/300], Train Loss: 0.0053, Val Loss: 0.0081
# Starting epoch 294/300
#   Batch 10/37, Loss: 0.0033
#   Batch 20/37, Loss: 0.0074
#   Batch 30/37, Loss: 0.0083
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000293.pth
# Deleted old checkpoint: epoch_000291.pth
# Epoch [294/300], Train Loss: 0.0054, Val Loss: 0.0080
# Starting epoch 295/300
#   Batch 10/37, Loss: 0.0057
#   Batch 20/37, Loss: 0.0056
#   Batch 30/37, Loss: 0.0058
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000294.pth
# Deleted old checkpoint: epoch_000292.pth
# Epoch [295/300], Train Loss: 0.0061, Val Loss: 0.0081
# Starting epoch 296/300
#   Batch 10/37, Loss: 0.0054
#   Batch 20/37, Loss: 0.0058
#   Batch 30/37, Loss: 0.0051
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000295.pth
# Deleted old checkpoint: epoch_000293.pth
# Epoch [296/300], Train Loss: 0.0055, Val Loss: 0.0080
# Starting epoch 297/300
#   Batch 10/37, Loss: 0.0066
#   Batch 20/37, Loss: 0.0097
#   Batch 30/37, Loss: 0.0129
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000296.pth
# Deleted old checkpoint: epoch_000294.pth
# Epoch [297/300], Train Loss: 0.0057, Val Loss: 0.0080
# Starting epoch 298/300
#   Batch 10/37, Loss: 0.0044
#   Batch 20/37, Loss: 0.0044
#   Batch 30/37, Loss: 0.0036
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000297.pth
# Deleted old checkpoint: epoch_000295.pth
# Epoch [298/300], Train Loss: 0.0057, Val Loss: 0.0081
# Starting epoch 299/300
#   Batch 10/37, Loss: 0.0109
#   Batch 20/37, Loss: 0.0059
#   Batch 30/37, Loss: 0.0040
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000298.pth
# Deleted old checkpoint: epoch_000296.pth
# Epoch [299/300], Train Loss: 0.0059, Val Loss: 0.0080
# Starting epoch 300/300
#   Batch 10/37, Loss: 0.0067
#   Batch 20/37, Loss: 0.0069
#   Batch 30/37, Loss: 0.0056
# Checkpoint saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/checkpoints/epoch_000299.pth
# Deleted old checkpoint: epoch_000297.pth
# Epoch [300/300], Train Loss: 0.0058, Val Loss: 0.0080
# Training complete. Best validation loss: 0.0078
# /tmp/ipykernel_159397/4222470777.py:169: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_checkpoint = torch.load(best_model_path, map_location=device)
# Loaded best model from epoch 187 with loss 0.0078
# Final model saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/proprioception_mlp.pth

# %% [markdown]
# ### Test the trained model

# %%
# Create the sensor processing module using the trained model
sp = MultiViewVitSensorProcessing(exp, device)

# Test it on a few validation examples
def test_multiview_sensor_processing(sp, test_view_inputs, test_targets, n_samples=5):
    """Test the multi-view sensor processing module on a few examples."""
    if n_samples > len(test_targets):
        n_samples = len(test_targets)

    # Get random indices
    indices = torch.randperm(len(test_targets))[:n_samples]

    print("\nTesting multi-view sensor processing on random examples:")
    print("-" * 60)

    for i, idx in enumerate(indices):
        # Get views and target
        views = [view[idx].unsqueeze(0).to(device) for view in test_view_inputs]  # Add batch dimension
        target = test_targets[idx].cpu().numpy()

        # Process the views to get the latent representation
        latent = sp.process(views)

        # Print the results
        print(f"Example {i+1}:")
        for j, view in enumerate(views):
            print(f"  View {j+1} shape: {view.shape}")
        print(f"  Latent shape: {latent.shape}")
        print(f"  Target position: {target}")
        print()

# Test the sensor processing
test_multiview_sensor_processing(sp, view_inputs_validation, targets_validation)
# Out:
# Initializing Multi-View ViT Sensor Processing:
#   Model: vit_l_16
#   Number of views: 2
#   Fusion type: gated
#   Latent dimension: 128
#   Image size: 224x224
# Using 2 x vit_l_16 with output dimension 1024
# Created gated fusion network
# Created proprioceptor: 128 → 64 → 64 → 6
# Feature extractors frozen. Projection and proprioceptor layers are trainable.
# Loading Multi-View ViT encoder weights from /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/proprioception_mlp.pth
# /lustre/fs1/home/ssheikholeslami/BerryPicker/src/sensorprocessing/../sensorprocessing/sp_vit_multiview.py:357: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.enc.load_state_dict(torch.load(modelfile, map_location=device))
# Testing multi-view sensor processing on random examples:
# ------------------------------------------------------------
# Example 1:
#   View 1 shape: torch.Size([1, 3, 256, 256])
#   View 2 shape: torch.Size([1, 3, 256, 256])
#   Latent shape: (128,)
#   Target position: [0.8857948  0.45419306 0.66338944 0.91739106 0.51170576 0.7944365 ]
#
# Example 2:
#   View 1 shape: torch.Size([1, 3, 256, 256])
#   View 2 shape: torch.Size([1, 3, 256, 256])
#   Latent shape: (128,)
#   Target position: [0.11979929 0.64397836 0.28895995 0.37931362 0.10096735 0.35096252]
#
# Example 3:
#   View 1 shape: torch.Size([1, 3, 256, 256])
#   View 2 shape: torch.Size([1, 3, 256, 256])
#   Latent shape: (128,)
#   Target position: [0.46494654 0.85770124 0.21145414 0.5182245  0.62526083 0.9698937 ]
#
# Example 4:
#   View 1 shape: torch.Size([1, 3, 256, 256])
#   View 2 shape: torch.Size([1, 3, 256, 256])
#   Latent shape: (128,)
#   Target position: [0.8515704  0.9489891  0.69166666 0.65402603 0.15616164 0.22596249]
#
# Example 5:
#   View 1 shape: torch.Size([1, 3, 256, 256])
#   View 2 shape: torch.Size([1, 3, 256, 256])
#   Latent shape: (128,)
#   Target position: [0.19495703 0.45450607 0.2056266  0.57185304 0.17943788 0.17799887]

# %% [markdown]
# ### Verify the model's encoding and forward methods

# %%
model.eval()
with torch.no_grad():
    # Get a sample set of views
    sample_views = [view[0].unsqueeze(0).to(device) for view in view_inputs_validation]

    # Get the latent representation using encode
    latent = model.encode(sample_views)
    print(f"Latent representation shape: {latent.shape}")

    # Get the robot position prediction using forward
    position = model.forward(sample_views)
    print(f"Robot position prediction shape: {position.shape}")

    # Check that the latent representation has the expected size
    expected_latent_size = exp["latent_size"]
    assert latent.shape[1] == expected_latent_size, f"Expected latent size {expected_latent_size}, got {latent.shape[1]}"

    # Check that the position prediction has the expected size
    expected_output_size = exp["output_size"]
    assert position.shape[1] == expected_output_size, f"Expected output size {expected_output_size}, got {position.shape[1]}"

    print("Verification successful!")
# Out:
# Latent representation shape: torch.Size([1, 128])
# Robot position prediction shape: torch.Size([1, 6])
# Verification successful!

# %% [markdown]
# ### Test the process_file method with cache handling

# %%
def test_process_file(sp, view_inputs_validation, n_samples=3):
    """Test the process_file method which handles view caching."""
    if n_samples > len(view_inputs_validation[0]):
        n_samples = len(view_inputs_validation[0])

    # Get first few samples
    indices = range(n_samples)

    print("\nTesting process_file method with view caching:")
    print("-" * 60)

    # Create temporary files to simulate image files
    import tempfile
    import os
    from torchvision.utils import save_image

    temp_dir = tempfile.mkdtemp()
    try:
        # Create temporary image files for testing
        for idx in indices:
            print(f"\nProcessing timestep {idx+1}:")

            # Create a file for each view at this timestep
            file_paths = []
            for view_idx, view_tensor in enumerate(view_inputs_validation):
                # Create file name with timestep and camera ID
                file_name = f"{idx+1:05d}_camera{view_idx+1}.jpg"
                file_path = os.path.join(temp_dir, file_name)

                # Save tensor as image
                save_image(view_tensor[idx], file_path)
                file_paths.append(file_path)

            # Test processing with all views available
            print("  Testing with all views available:")
            for view_idx, file_path in enumerate(file_paths):
                latent = sp.process_file(file_path, camera_id=f"camera{view_idx+1}")
                print(f"    Processed view {view_idx+1}, latent shape: {latent.shape}")

            # Test processing with missing views (if we have more than one view)
            if len(file_paths) > 1:
                print("  Testing with one missing view:")
                # Clear cache to simulate new scenario
                if hasattr(sp, '_view_cache'):
                    sp._view_cache = {}
                    sp._timestep_cache = {}

                # Process only one view and see if cache is updated
                latent = sp.process_file(file_paths[0], camera_id=f"camera1")
                print(f"    Processed only view 1, latent shape: {latent.shape}")

                # Now process a different view and see if previous view is used from cache
                latent = sp.process_file(file_paths[1], camera_id=f"camera2")
                print(f"    Processed view 2 with view 1 from cache, latent shape: {latent.shape}")

    finally:
        # Clean up temporary directory
        import shutil
        shutil.rmtree(temp_dir)

# Test the process_file method with caching
test_process_file(sp, view_inputs_validation)
# Out:
# Testing process_file method with view caching:
# ------------------------------------------------------------
#
# Processing timestep 1:
#   Testing with all views available:
# Using 1 unique views (with 1 duplicated)
#     Processed view 1, latent shape: (128,)
# Using complete set of 2 views from timestep 1
#     Processed view 2, latent shape: (128,)
#   Testing with one missing view:
# Using 1 unique views (with 1 duplicated)
#     Processed only view 1, latent shape: (128,)
# Using complete set of 2 views from timestep 1
#     Processed view 2 with view 1 from cache, latent shape: (128,)
#
# Processing timestep 2:
#   Testing with all views available:
# Using 2 unique views (with 0 duplicated)
#     Processed view 1, latent shape: (128,)
# Using complete set of 2 views from timestep 2
#     Processed view 2, latent shape: (128,)
#   Testing with one missing view:
# Using 1 unique views (with 1 duplicated)
#     Processed only view 1, latent shape: (128,)
# Using complete set of 2 views from timestep 2
#     Processed view 2 with view 1 from cache, latent shape: (128,)
#
# Processing timestep 3:
#   Testing with all views available:
# Using 2 unique views (with 0 duplicated)
#     Processed view 1, latent shape: (128,)
# Using complete set of 2 views from timestep 3
#     Processed view 2, latent shape: (128,)
#   Testing with one missing view:
# Using 1 unique views (with 1 duplicated)
#     Processed only view 1, latent shape: (128,)
# Using complete set of 2 views from timestep 3
#     Processed view 2 with view 1 from cache, latent shape: (128,)

# %% [markdown]
# ### Save final model and print summary

# %%
final_modelfile = pathlib.Path(exp["data_dir"], exp["proprioception_mlp_model_file"])
torch.save(model.state_dict(), final_modelfile)
print(f"Model saved to {final_modelfile}")

print("\nTraining complete!")
print(f"Vision Transformer type: {exp['vit_model']}")
print(f"Number of views: {exp.get('num_views', 2)}")
print(f"Fusion type: {exp.get('fusion_type', 'concat_proj')}")
print(f"Latent space dimension: {exp['latent_size']}")
print(f"Output dimension (robot DOF): {exp['output_size']}")
print(f"Use the MultiViewVitSensorProcessing class to load and use this model for inference.")
# Out:
# Model saved to /home/ssheikholeslami/SaharaBerryPickerData/experiment_data/sensorprocessing_propriotuned_Vit_multiview/vit_large_multiview_gated/proprioception_mlp.pth
#
# Training complete!
# Vision Transformer type: vit_l_16
# Number of views: 2
# Fusion type: gated
# Latent space dimension: 128
# Output dimension (robot DOF): 6
# Use the MultiViewVitSensorProcessing class to load and use this model for inference.
