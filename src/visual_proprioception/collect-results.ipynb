# %%
import pathlib
import shutil

# %%
target = "target"
external_path = r"C:\Users\lotzi\Work\_Data\BerryPicker-Flows"

root_path = pathlib.Path(external_path)

for i in range(112):
    name = f"cvpr_simulation_{i:03d}"
    print(name)
    source_path = pathlib.Path(root_path, name, "results", "visual_proprioception", "vp_comp_flow_all")
    target_path = pathlib.Path(root_path, target, name, "results", "visual_proprioception", "vp_comp_flow_all")
    target_path.mkdir(exist_ok = True, parents=True)
    shutil.copy(pathlib.Path(source_path,"all_msecomparison_values.csv"), pathlib.Path(target_path,"all_msecomparison_values.csv"))
    shutil.copy(pathlib.Path(source_path,"msecomparison_values.txt"), pathlib.Path(target_path,"msecomparison_values.txt"))
