# %% [markdown]
# # Verify models for visual proprioception
#
# Verifies a regression model for visual proprioception, as trained in the notebook Train_VisualProprioception
#
# The encoding and the regressor is specified in an experiment of type visual_proprioception.

# %%
import sys
sys.path.append("..")
from exp_run_config import Config
Config.PROJECTNAME = "BerryPicker"

import pathlib
from pprint import pprint
import matplotlib.pyplot as plt
# fixing the fact that it defaults to Type 3 fonts
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

import numpy as np
import torch

torch.manual_seed(1)

# from robot.al5d import RobotPosition

from visual_proprioception.visproprio_helper import predict_positions

device = Config().runtime["device"]
print(f"Using device: {device}")

# %%
experiment = "visual_proprioception"

# the latent space 128 ones
# run = "vp_aruco_128"
# run = "vp_convvae_128"
run = "vp_ptun_vgg19_128"
# run = "vp_ptun_resnet50_128"

# the latent space 256 ones
# run = "vp_convvae_256"
# run = "vp_ptun_vgg19_256"
# run = "vp_ptun_resnet50_256"

# position-filtered variants; these reuse the base run's trained regressor
# run = "vp_ptun_vgg19_128_ema"
# run = "vp_ptun_vgg19_128_kalman"
# run = "vp_convvae_128_ema"
# run = "vp_convvae_128_kalman"

exp = Config().get_experiment(experiment, run)
pprint(exp)

exp_robot = Config().get_experiment(exp["robot_exp"], exp["robot_run"])

# %%
# Run the regressor over the validation demonstrations. This resolves the
# base run for the sensor processor, the trained weights and the cached
# latents, and applies the position filter the exp/run configures.

result = predict_positions(exp, exp_robot, "validation_data")

y = result["targets"]
ypred = result["predictions"]
yfiltered = result["filtered"]
t = np.arange(len(y))

print(f"There are {len(y)} data points in "
      f"{len(result['lengths'])} demonstrations: {result['lengths']}")
print(f"Position filter: {exp['position_filter']}")

# %% [markdown]
# ## Accuracy in time multigraph
# Visualize the accuracy of the proprioception on the testing task, by plotting the ground truth.

# %%
titles = ["height", "distance", "heading",
          "wrist_angle", "wrist_rotation", "gripper"]

# Per-field RMSE in normalized units, the same metric the Compare notebook
# reports. With position_filter 'none' the two columns are identical.
print(f"{'field':<16}{'unfiltered':>12}{'filtered':>10}{'gain':>8}")
for i, title in enumerate(titles):
    raw = np.sqrt(np.mean((ypred[:, i] - y[:, i]) ** 2))
    filtered = np.sqrt(np.mean((yfiltered[:, i] - y[:, i]) ** 2))
    print(f"{title:<16}{raw:12.4f}{filtered:10.4f}{raw / filtered:7.2f}x")

outside = np.mean((yfiltered < 0) | (yfiltered > 1))
outside_raw = np.mean((ypred < 0) | (ypred > 1))
print(f"\nPredictions outside [0, 1]: {outside_raw:.3%} unfiltered, "
      f"{outside:.3%} filtered")

# %% [markdown]
# Create a graph with the six degrees of freedom, predicted and real value

# %%
fig, axs = plt.subplots(2, 3, constrained_layout=True)
#for i in range(Config()["robot"]["action_space_size"]):
for i in range(6):
    ax = axs[i//3, i%3]
    ax.set_ylim(0, 1)
    ax.plot(t, y[:, i], label="y", color="black", linewidth=1.5)
    ax.plot(t, ypred[:, i], label="yhat", linewidth=0.8, alpha=0.6)
    if exp["position_filter"] != "none":
        ax.plot(t, yfiltered[:, i], label="filtered", linewidth=1.2)
    ax.legend(fontsize=6)
    ax.set_title(titles[i])

# Demonstration boundaries: the filter is reset at each one.
for boundary in np.cumsum(result["lengths"])[:-1]:
    for ax in axs.flat:
        ax.axvline(boundary, color="gray", linestyle=":", linewidth=0.8)

graphfilename = pathlib.Path(exp["data_dir"], "proprio_error.pdf")
plt.savefig(graphfilename)

# %%
POS_MAX = {"height": 5.0, "distance": 10.0, "heading": 90.0,
               "wrist_angle": 90.0, "wrist_rotation": 75.0 + 90.0,
               "gripper": 100}

# %%
for i, fld in enumerate(POS_MAX):
    print(i, fld)
